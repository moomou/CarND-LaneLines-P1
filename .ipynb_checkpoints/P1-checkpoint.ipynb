# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
#
# ## Project: **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# In addition to implementing code, there is a brief writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) that can be used to guide the writing process. Completing both the code in the Ipython notebook and the writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/322/view) for this project.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="examples/line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="examples/laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %% [markdown]
# **Run the cell below to import some packages.  If you get an `import error` for a package you've already installed, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt.  Also, consult the forums for more troubleshooting tips.**

# %% [markdown]
# ## Import Packages

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %%
# !ls
# Out:
# P1.ipynb  README.md  examples  test_images  test_videos  writeup_template.md

# %% [markdown]
# ## Read in an Image

# %%
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')

#printing out some stats and plotting
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)  # if you wanted to show a single color channel image called 'gray', for example, call as plt.imshow(gray, cmap='gray')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %% [markdown]
# ## Ideas for Lane Detection Pipeline

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %% [markdown]
# ## Test Images
#
# Build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
# Out:
# ['solidYellowCurve.jpg',
#  'solidYellowLeft.jpg',
#  'solidYellowCurve2.jpg',
#  'solidWhiteRight.jpg',
#  'whiteCarLaneSwitch.jpg',
#  'solidWhiteCurve.jpg']

# %% [markdown]
# ## Build a Lane Finding Pipeline

# %% [markdown]
# Build the pipeline and run your solution on all test_images. Make copies into the `test_images_output` directory, and you can use the images in your writeup report.
#
# Try tuning the various parameters, especially the low and high Canny thresholds as well as the Hough lines parameters.

# %%
import pipe
from importlib import reload

# %%
image = mpimg.imread('test_images/whiteCarLaneSwitch.jpg')
pipe = reload(pipe)
im = pipe.detect_lane(image)
plt.imshow(im, cmap='gray')

# %%
image = mpimg.imread('test_images/whiteCarLaneSwitch.jpg')
pipe = reload(pipe)
im = pipe.detect_lane(image)
plt.imshow(im, cmap='gray')

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`
#
# **Note: if you get an import error when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel). Still have problems? Try relaunching Jupyter Notebook from the terminal prompt. Also, consult the forums for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://discussions.udacity.com/t/project-error-of-test-on-videos/274082) for more troubleshooting tips across operating systems.**

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
data = [-42.399998989105249]
print(np.mean(data))
print(np.std(data))
abs(data - np.mean(data)) <= 2 * np.std(data)
# Out:
# -42.3999989891
# 0.0
# array([ True], dtype=bool)

# %%
pipe = reload(pipe)

def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)
    result = pipe.detect_lane(image)
    print('done')
    return result

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'test_videos_output/solidWhiteRight.mp4'
clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4") #.subclip(0, 0.15)
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# left line
# y = [-0.76819187]x + 669
# right line
# y = [ 0.61501527]x + 10
# done
# [MoviePy] >>>> Building video test_videos_output/solidWhiteRight.mp4
# [MoviePy] Writing video test_videos_output/solidWhiteRight.mp4
#   0%|          | 0/222 [00:00<?, ?it/s]
#   2%|▏         | 5/222 [00:00<00:05, 42.29it/s]
# left line
# y = [-0.76819187]x + 669
# right line
# y = [ 0.61501527]x + 10
# done
# left line
# y = [-0.74096119]x + 657
# right line
# y = [ 0.6123963]x + 11
# done
# left line
# y = [-0.72547942]x + 652
# right line
# y = [ 0.61506116]x + 12
# done
# left line
# y = [-0.6748758]x + 629
# right line
# y = [ 0.62019014]x + 7
# done
# left line
# y = [-0.71668231]x + 647
# right line
# y = [ 0.62169003]x + 6
# done
# left line
# y = [-0.72457951]x + 651
# right line
# y = [ 0.61946487]x + 7
# done
# left line
# y = [-0.71110123]x + 646
# right line
# y = [ 0.61229187]x + 9
# done
# left line
# y = [-0.71579635]x + 647
# right line
# y = [ 0.61371171]x + 10
# done
# left line
# y = [-0.70914906]x + 645
# right line
# y = [ 0.6363796]x + -1
# done
#   4%|▍         | 9/222 [00:00<00:05, 40.57it/s]
#   6%|▌         | 13/222 [00:00<00:05, 39.43it/s]
# left line
# y = [-0.70805961]x + 645
# right line
# y = [ 0.63626677]x + -1
# done
# left line
# y = [-0.71106398]x + 650
# right line
# y = [ 0.62454152]x + 8
# done
# left line
# y = [-0.72234315]x + 654
# right line
# y = [ 0.61300945]x + 17
# done
# left line
# y = [-0.72389841]x + 654
# right line
# y = [ 0.61316037]x + 18
# done
# left line
# y = [-0.68815494]x + 636
# right line
# y = [ 0.62804657]x + 6
# done
# left line
# y = [-0.70091939]x + 641
# right line
# y = [ 0.64047319]x + 0
# done
#   8%|▊         | 17/222 [00:00<00:05, 38.65it/s]
# left line
# y = [-0.75001127]x + 657
# right line
# y = [ 0.65849942]x + -13
# done
# left line
# y = [-0.71203816]x + 642
# right line
# y = [ 0.66046125]x + -14
# done
#  10%|▉         | 22/222 [00:00<00:05, 39.10it/s]
# left line
# y = [-0.71291208]x + 643
# right line
# y = [ 0.64160252]x + -4
# done
# left line
# y = [-0.69816822]x + 639
# right line
# y = [ 0.64381284]x + -2
# done
# left line
# y = [-0.70812815]x + 647
# right line
# y = [ 0.63643944]x + 2
# done
# left line
# y = [-0.697276]x + 643
# right line
# y = [ 0.63581234]x + 2
# done
# left line
# y = [-0.69758755]x + 643
# right line
# y = [ 0.63560855]x + 1
# done
# left line
# y = [-0.7323522]x + 656
# right line
# y = [ 0.64058918]x + 0
# done
# left line
# y = [-0.73979378]x + 661
# right line
# y = [ 0.64103723]x + -1
# done
# left line
# y = [-0.70725667]x + 645
# right line
# y = [ 0.6441474]x + -3
# done
#  12%|█▏        | 26/222 [00:00<00:05, 35.72it/s]
# left line
# y = [-0.7356773]x + 657
# right line
# y = [ 0.64896572]x + -6
# done
# left line
# y = [-0.69715667]x + 642
# right line
# y = [ 0.66247529]x + -13
# done
# left line
# y = [-0.75252533]x + 662
# right line
# y = [ 0.63997805]x + 0
# done
# left line
# y = [-0.6749081]x + 632
# right line
# y = [ 0.62632853]x + 7
# done
#  14%|█▎        | 30/222 [00:00<00:05, 35.91it/s]
# left line
# y = [-0.73851258]x + 657
# right line
# y = [ 0.63544899]x + 0
# done
# left line
# y = [-0.69813824]x + 640
# right line
# y = [ 0.62022161]x + 11
# done
# left line
# y = [-0.70580178]x + 644
# right line
# y = [ 0.65250915]x + -11
# done
# left line
# y = [-0.72073472]x + 650
# right line
#  15%|█▌        | 34/222 [00:00<00:05, 35.62it/s]
# y = [ 0.615996]x + 9
# done
# left line
# y = [-0.68355536]x + 633
# right line
# y = [ 0.63743895]x + -4
# done
# left line
# y = [-0.75237221]x + 664
# right line
# y = [ 0.62690616]x + 4
# done
# left line
# y = [-0.70107931]x + 643
# right line
# y = [ 0.63588977]x + 0
# done
# left line
# y = [-0.69992048]x + 643
# right line
# y = [ 0.64489698]x + -2
# done
#  17%|█▋        | 38/222 [00:01<00:05, 36.67it/s]
# left line
# y = [-0.72031909]x + 650
# right line
# y = [ 0.63797104]x + 0
# done
# left line
# y = [-0.70149416]x + 642
# right line
# y = [ 0.66520357]x + -18
# done
# left line
# y = [-0.70127434]x + 641
# right line
# y = [ 0.64938587]x + -9
# done
# left line
# y = [-0.72369051]x + 650
# right line
# y = [ 0.64893377]x + -9
# done
# left line
# y = [-0.72003359]x + 648
# right line
# y = [ 0.64469814]x + -7
# done
#  19%|█▉        | 42/222 [00:01<00:05, 30.06it/s]
# left line
# y = [-0.70782304]x + 643
# right line
# y = [ 0.63824123]x + -3
# done
#  21%|██        | 46/222 [00:01<00:06, 25.65it/s]
# left line
# y = [-0.70844913]x + 643
# right line
# y = [ 0.64648342]x + -8
# done
# left line
# y = [-0.68397814]x + 632
# right line
# y = [ 0.64256871]x + -6
# done
# left line
# y = [-0.7098518]x + 644
# right line
# y = [ 0.65087342]x + -9
# done
# left line
# y = [-0.75256455]x + 661
# right line
# y = [ 0.6509611]x + -10
# done
#  22%|██▏       | 49/222 [00:01<00:09, 18.17it/s]
# left line
# y = [-0.72080457]x + 646
# right line
# y = [ 0.63628978]x + 0
# done
# left line
# y = [-0.68161684]x + 631
# right line
# y = [ 0.65163481]x + -11
# done
# left line
# y = [-0.72500652]x + 651
# right line
# y = [ 0.65636927]x + -13
# done
# left line
# y = [-0.68313396]x + 632
# right line
# y = [ 0.6506831]x + -9
# done
#  23%|██▎       | 52/222 [00:01<00:09, 17.28it/s]
#  25%|██▍       | 55/222 [00:02<00:09, 18.14it/s]
# left line
# y = [-0.71015072]x + 642
# right line
# y = [ 0.63960832]x + -3
# done
# left line
# y = [-0.69286203]x + 635
# right line
# y = [ 0.64251685]x + -3
# done
# left line
# y = [-0.66225481]x + 622
# right line
# y = [ 0.65862173]x + -13
# done
# left line
# y = [-0.68858278]x + 633
# right line
# y = [ 0.6387313]x + 0
# done
#  26%|██▌       | 58/222 [00:02<00:09, 16.53it/s]
# left line
# y = [-0.68472177]x + 632
# right line
# y = [ 0.64436746]x + -4
# done
# left line
# y = [-0.68423903]x + 633
# right line
# y = [ 0.64740092]x + -2
# done
# left line
# y = [-0.68785459]x + 636
# right line
# y = [ 0.61111134]x + 22
# done
#  27%|██▋       | 61/222 [00:02<00:09, 17.63it/s]
# left line
# y = [-0.68456727]x + 633
# right line
# y = [ 0.64236051]x + -1
# done
# left line
# y = [-0.65931028]x + 622
# right line
# y = [ 0.65294248]x + -8
# done
# left line
# y = [-0.65965575]x + 623
# right line
# y = [ 0.62128973]x + 14
# done
# left line
# y = [-0.66816628]x + 627
# right line
# y = [ 0.63836461]x + 0
# done
# left line
# y = [-0.66964614]x + 627
# right line
# y = [ 0.63856167]x + 0
# done
#  29%|██▉       | 64/222 [00:02<00:08, 18.85it/s]
# left line
# y = [-0.67252594]x + 629
# right line
# y = [ 0.65271509]x + -8
# done
# left line
# y = [-0.67309409]x + 629
# right line
# y = [ 0.64521068]x + -4
# done
# left line
# y = [-0.6562714]x + 621
# right line
# y = [ 0.63757765]x + 2
# done
# left line
# y = [-0.64799255]x + 617
# right line
# y = [ 0.63707012]x + 1
# done
#  30%|███       | 67/222 [00:02<00:08, 18.19it/s]
#  31%|███       | 69/222 [00:02<00:08, 17.76it/s]
# left line
# y = [-0.67193294]x + 626
# right line
# y = [ 0.63620764]x + 0
# done
# left line
# y = [-0.67128974]x + 626
# right line
# y = [ 0.64481181]x + -6
# done
# left line
# y = [-0.66029596]x + 623
# right line
# y = [ 0.6682741]x + -15
# done
# left line
# y = [-0.63235664]x + 610
# right line
# y = [ 0.65747464]x + -10
# done
# left line
# y = [-0.653431]x + 618
# right line
# y = [ 0.65517366]x + -10
# done
#  32%|███▏      | 72/222 [00:02<00:07, 19.05it/s]
#  33%|███▎      | 74/222 [00:03<00:07, 18.92it/s]
# left line
# y = [-0.65874231]x + 621
# right line
# y = [ 0.66505945]x + -12
# done
# left line
# y = [-0.69814801]x + 637
# right line
# y = [ 0.65175849]x + -6
# done
# left line
# y = [-0.68894112]x + 634
# right line
# y = [ 0.64842713]x + -1
# done
# left line
# y = [-0.67051655]x + 625
# right line
# y = [ 0.66310948]x + -12
# done
# left line
# y = [-0.65061599]x + 616
# right line
# y = [ 0.6409322]x + 4
# done
#  35%|███▍      | 77/222 [00:03<00:07, 20.16it/s]
#  36%|███▌      | 80/222 [00:03<00:07, 19.96it/s]
# left line
# y = [-0.6456809]x + 613
# right line
# y = [ 0.66557395]x + -10
# done
# left line
# y = [-0.66858661]x + 624
# right line
# y = [ 0.71088731]x + -38
# done
# left line
# y = [-0.6340099]x + 611
# right line
# y = [ 0.67626029]x + -19
# done
# left line
# y = [-0.67507297]x + 626
# right line
# y = [ 0.66875178]x + -16
# done
#  37%|███▋      | 83/222 [00:03<00:07, 19.09it/s]
# left line
# y = [-0.62327296]x + 605
# right line
# y = [ 0.66438836]x + -14
# done
# left line
# y = [-0.66998672]x + 624
# right line
# y = [ 0.66753137]x + -16
# done
# left line
# y = [-0.66317499]x + 622
# right line
# y = [ 0.66087949]x + -11
# done
# left line
# y = [-0.64131927]x + 611
# right line
# y = [ 0.6732825]x + -17
# done
# left line
# y = [-0.65977371]x + 620
# right line
# y = [ 0.66944087]x + -17
# done
#  39%|███▊      | 86/222 [00:03<00:07, 19.16it/s]
#  40%|████      | 89/222 [00:03<00:06, 19.16it/s]
# left line
# y = [-0.619403]x + 602
# right line
# y = [ 0.66164035]x + -10
# done
# left line
# y = [-0.66284454]x + 622
# right line
# y = [ 0.67641401]x + -19
# done
# left line
# y = [-0.65601039]x + 620
# right line
# y = [ 0.67916483]x + -20
# done
# left line
# y = [-0.6587078]x + 620
# right line
# y = [ 0.69322479]x + -28
# done
#  41%|████▏     | 92/222 [00:03<00:06, 20.39it/s]
# left line
# y = [-0.66038787]x + 622
# right line
# y = [ 0.68538302]x + -23
# done
# left line
# y = [-0.6560455]x + 621
# right line
# y = [ 0.68124694]x + -21
# done
# left line
# y = [-0.65939099]x + 623
# right line
# y = [ 0.687738]x + -25
# done
# left line
# y = [-0.6598978]x + 623
# right line
# y = [ 0.67643458]x + -18
# done
# left line
#  43%|████▎     | 95/222 [00:04<00:06, 19.77it/s]
# y = [-0.68590945]x + 634
# right line
# y = [ 0.70288974]x + -36
# done
# left line
# y = [-0.65328968]x + 619
# right line
# y = [ 0.69280416]x + -29
# done
# left line
# y = [-0.67507476]x + 628
# right line
# y = [ 0.70463818]x + -38
# done
#  44%|████▍     | 98/222 [00:04<00:08, 13.78it/s]
#  45%|████▌     | 100/222 [00:04<00:08, 13.89it/s]
# left line
# y = [-0.69863015]x + 635
# right line
# y = [ 0.70045501]x + -39
# done
# left line
# y = [-0.65894532]x + 621
# right line
# y = [ 0.69284207]x + -31
# done
# left line
# y = [-0.6836369]x + 630
# right line
# y = [ 0.70645422]x + -41
# done
# left line
# y = [-0.66115761]x + 622
#  46%|████▌     | 102/222 [00:04<00:09, 13.24it/s]
# right line
# y = [ 0.69824839]x + -35
# done
# left line
# y = [-0.65700418]x + 623
# right line
# y = [ 0.6824531]x + -25
# done
# left line
# y = [-0.6704734]x + 629
# right line
#  47%|████▋     | 104/222 [00:04<00:09, 12.28it/s]
# y = [ 0.70991051]x + -38
# done
# left line
# y = [-0.68270522]x + 635
# right line
# y = [ 0.70273405]x + -34
# done
# left line
# y = [-0.66517097]x + 629
# right line
# y = [ 0.7063033]x + -37
# done
# left line
# y = [-0.69114316]x + 636
# right line
# y = [ 0.67863655]x + -23
# done
#  48%|████▊     | 106/222 [00:05<00:09, 12.70it/s]
#  49%|████▊     | 108/222 [00:05<00:09, 12.32it/s]
# left line
# y = [-0.67034167]x + 627
# right line
# y = [ 0.67728168]x + -24
# done
# left line
# y = [-0.66158825]x + 623
# right line
# y = [ 0.6956389]x + -31
# done
# left line
# y = [-0.68959367]x + 637
# right line
# y = [ 0.68266618]x + -28
# done
#  50%|████▉     | 110/222 [00:05<00:08, 12.60it/s]
#  50%|█████     | 112/222 [00:05<00:07, 13.89it/s]
# left line
# y = [-0.65711182]x + 623
# right line
# y = [ 0.68341529]x + -28
# done
# left line
# y = [-0.64705884]x + 622
# right line
# y = [ 0.66267431]x + -14
# done
# left line
# y = [-0.65943086]x + 624
# right line
# y = [ 0.68373781]x + -28
# done
# left line
# y = [-0.66541171]x + 627
# right line
# y = [ 0.65836334]x + -13
# done
# left line
# y = [-0.69435167]x + 640
# right line
# y = [ 0.66289949]x + -15
# done
#  51%|█████▏    | 114/222 [00:05<00:07, 14.22it/s]
#  52%|█████▏    | 116/222 [00:05<00:07, 13.61it/s]
# left line
# y = [-0.676328]x + 631
# right line
# y = [ 0.6474458]x + -8
# done
# left line
# y = [-0.66431451]x + 626
# right line
# y = [ 0.67079663]x + -22
# done
# left line
# y = [-0.64836127]x + 620
# right line
# y = [ 0.64143562]x + 0
# done
#  53%|█████▎    | 118/222 [00:06<00:07, 13.67it/s]
#  54%|█████▍    | 120/222 [00:06<00:06, 14.65it/s]
# left line
# y = [-0.66200787]x + 625
# right line
# y = [ 0.65799665]x + -13
# done
# left line
# y = [-0.65637457]x + 623
# right line
# y = [ 0.67315459]x + -22
# done
# left line
# y = [-0.66195279]x + 627
# right line
# y = [ 0.66013229]x + -14
# done
# left line
# y = [-0.66796261]x + 628
# right line
# y = [ 0.66746229]x + -17
# done
#  55%|█████▍    | 122/222 [00:06<00:07, 13.68it/s]
#  56%|█████▋    | 125/222 [00:06<00:06, 15.51it/s]
# left line
# y = [-0.66397715]x + 628
# right line
# y = [ 0.61721331]x + 14
# done
# left line
# y = [-0.70045376]x + 643
# right line
# y = [ 0.64077425]x + -3
# done
# left line
# y = [-0.69997913]x + 644
# right line
# y = [ 0.63239443]x + 1
# done
# left line
# y = [-0.69964039]x + 643
# right line
# y = [ 0.6545338]x + -11
# done
# left line
# y = [-0.69329417]x + 641
# right line
# y = [ 0.61292416]x + 16
# done
#  57%|█████▋    | 127/222 [00:06<00:05, 15.89it/s]
#  58%|█████▊    | 129/222 [00:06<00:05, 16.09it/s]
# left line
# y = [-0.68022615]x + 635
# right line
# y = [ 0.61711848]x + 10
# done
# left line
# y = [-0.70512158]x + 646
# right line
# y = [ 0.61763316]x + 9
# done
# left line
# y = [-0.67258102]x + 632
# right line
# y = [ 0.60970658]x + 14
# done
# left line
# y = [-0.69723284]x + 645
# right line
# y = [ 0.63211101]x + 1
# done
#  59%|█████▉    | 131/222 [00:06<00:05, 17.09it/s]
#  60%|█████▉    | 133/222 [00:06<00:05, 15.07it/s]
# left line
# y = [-0.6997788]x + 645
# right line
# y = [ 0.60758942]x + 17
# done
# left line
# y = [-0.74979877]x + 666
# right line
# y = [ 0.60975122]x + 15
# done
# left line
# y = [-0.69536155]x + 644
# right line
# y = [ 0.60069305]x + 23
# done
#  61%|██████▏   | 136/222 [00:07<00:05, 15.76it/s]
# left line
# y = [-0.72388774]x + 654
# right line
# y = [ 0.62126094]x + 10
# done
# left line
# y = [-0.6627652]x + 629
# right line
# y = [ 0.61367601]x + 10
# done
# left line
# y = [-0.70981562]x + 646
# right line
# y = [ 0.6092822]x + 14
# done
# left line
# y = [-0.68790543]x + 635
# right line
# y = [ 0.62902427]x + -4
# done
# left line
#  63%|██████▎   | 139/222 [00:07<00:04, 17.59it/s]
#  64%|██████▎   | 141/222 [00:07<00:04, 16.66it/s]
# y = [-0.71072274]x + 646
# right line
# y = [ 0.61972797]x + 3
# done
# left line
# y = [-0.71045762]x + 648
# right line
# y = [ 0.62166768]x + 6
# done
# left line
# y = [-0.71132815]x + 648
# right line
# y = [ 0.62464648]x + 5
# done
# left line
# y = [-0.69978833]x + 644
# right line
# y = [ 0.62594199]x + 4
# done
#  64%|██████▍   | 143/222 [00:07<00:04, 16.53it/s]
#  65%|██████▌   | 145/222 [00:07<00:04, 17.31it/s]
# left line
# y = [-0.70966375]x + 650
# right line
# y = [ 0.63250762]x + 1
# done
# left line
# y = [-0.71232909]x + 651
# right line
# y = [ 0.60218602]x + 21
# done
# left line
# y = [-0.7120679]x + 652
# right line
# y = [ 0.63250571]x + 3
# done
# left line
# y = [-0.70822936]x + 649
# right line
# y = [ 0.59613574]x + 26
# done
#  66%|██████▌   | 147/222 [00:07<00:04, 17.59it/s]
#  67%|██████▋   | 149/222 [00:07<00:04, 17.67it/s]
# left line
# y = [-0.71280146]x + 651
# right line
# y = [ 0.61299568]x + 14
# done
# left line
# y = [-0.71037316]x + 649
# right line
# y = [ 0.60423446]x + 20
# done
# left line
# y = [-0.69875354]x + 643
# right line
# y = [ 0.63644516]x + -5
# done
# left line
# y = [-0.71959054]x + 652
# right line
# y = [ 0.63186759]x + -2
# done
#  68%|██████▊   | 151/222 [00:07<00:04, 16.31it/s]
# left line
# y = [-0.7471084]x + 664
# right line
# y = [ 0.63154554]x + -2
# done
# left line
# y = [-0.73153162]x + 659
# right line
# y = [ 0.64188433]x + -9
# done
# left line
# y = [-0.73970485]x + 664
# right line
# y = [ 0.63045257]x + -1
# done
# left line
# y = [-0.71307617]x + 652
# right line
# y = [ 0.6020093]x + 14
# done
# left line
#  69%|██████▉   | 154/222 [00:08<00:03, 18.25it/s]
#  70%|███████   | 156/222 [00:08<00:03, 16.94it/s]
# y = [-0.72301811]x + 655
# right line
# y = [ 0.6309498]x + -1
# done
# left line
# y = [-0.68707883]x + 640
# right line
# y = [ 0.61620295]x + 4
# done
# left line
# y = [-0.7398628]x + 660
# right line
# y = [ 0.61303151]x + 5
# done
# left line
# y = [-0.72798723]x + 657
# right line
# y = [ 0.6136741]x + 6
# done
# left line
#  72%|███████▏  | 159/222 [00:08<00:03, 18.57it/s]
#  73%|███████▎  | 161/222 [00:08<00:03, 17.70it/s]
# y = [-0.72054708]x + 654
# right line
# y = [ 0.62454253]x + 2
# done
# left line
# y = [-0.72502416]x + 653
# right line
# y = [ 0.62525302]x + 0
# done
# left line
# y = [-0.72924209]x + 659
# right line
# y = [ 0.59639865]x + 18
# done
# left line
# y = [-0.711281]x + 650
# right line
# y = [ 0.60873216]x + 10
# done
#  73%|███████▎  | 163/222 [00:08<00:03, 17.10it/s]
# left line
# y = [-0.76327938]x + 673
# right line
# y = [ 0.62885737]x + -3
# done
# left line
# y = [-0.74656057]x + 667
# right line
# y = [ 0.58620453]x + 25
# done
# left line
# y = [-0.76500422]x + 675
# right line
# y = [ 0.58704484]x + 25
# done
#  74%|███████▍  | 165/222 [00:08<00:03, 14.89it/s]
#  75%|███████▌  | 167/222 [00:08<00:03, 15.14it/s]
# left line
# y = [-0.75545233]x + 671
# right line
# y = [ 0.54857028]x + 47
# done
# left line
# y = [-0.73964441]x + 664
# right line
# y = [ 0.56695431]x + 36
# done
# left line
# y = [-0.73651665]x + 668
# right line
# y = [ 0.55304068]x + 47
# done
#  76%|███████▌  | 169/222 [00:09<00:03, 14.44it/s]
# left line
# y = [-0.75151849]x + 671
# right line
# y = [ 0.54226327]x + 56
# done
# left line
# y = [-0.7497136]x + 670
# right line
# y = [ 0.52787578]x + 60
# done
# left line
# y = [-0.77053452]x + 678
# right line
# y = [ 0.58805734]x + 25
# done
#  77%|███████▋  | 171/222 [00:09<00:04, 12.38it/s]
# left line
# y = [-0.73382282]x + 662
# right line
# y = [ 0.59724015]x + 18
# done
# left line
# y = [-0.75941366]x + 674
# right line
# y = [ 0.592026]x + 21
# done
# left line
# y = [-0.80476505]x + 691
# right line
# y = [ 0.55664796]x + 41
# done
#  78%|███████▊  | 173/222 [00:09<00:04, 12.03it/s]
#  79%|███████▉  | 175/222 [00:09<00:03, 12.54it/s]
# left line
# y = [-0.72331482]x + 660
# right line
# y = [ 0.57901323]x + 29
# done
# left line
# y = [-0.73382699]x + 662
# right line
# y = [ 0.59686691]x + 18
# done
# left line
# y = [-0.77451706]x + 682
# right line
# y = [ 0.5858528]x + 25
# done
#  80%|███████▉  | 177/222 [00:09<00:03, 12.37it/s]
# left line
# y = [-0.77884978]x + 684
# right line
# y = [ 0.59552532]x + 18
# done
# left line
# y = [-0.79654706]x + 691
# right line
# y = [ 0.59917891]x + 17
# done
# left line
# y = [-0.78723919]x + 685
#  81%|████████  | 179/222 [00:09<00:03, 12.44it/s]
# right line
# y = [ 0.59316319]x + 20
# done
# left line
# y = [-0.78377652]x + 683
# right line
# y = [ 0.59599763]x + 17
# done
# left line
# y = [-0.847157]x + 709
# right line
# y = [ 0.60871023]x + 9
# done
#  82%|████████▏ | 181/222 [00:10<00:03, 11.63it/s]
#  82%|████████▏ | 183/222 [00:10<00:03, 12.70it/s]
# left line
# y = [-0.77572185]x + 680
# right line
# y = [ 0.60858053]x + 8
# done
# left line
# y = [-0.78385252]x + 683
# right line
# y = [ 0.60923594]x + 7
# done
# left line
# y = [-0.78048784]x + 679
# right line
# y = [ 0.63928336]x + -6
# done
#  83%|████████▎ | 185/222 [00:10<00:03, 11.16it/s]
# left line
# y = [-0.86343789]x + 711
# right line
# y = [ 0.6021446]x + 11
# done
# left line
# y = [-0.74721563]x + 668
# right line
# y = [ 0.5959782]x + 16
# done
# left line
# y = [-0.7431823]x + 667
# right line
# y = [ 0.60075045]x + 15
# done
#  84%|████████▍ | 187/222 [00:10<00:03, 11.53it/s]
#  85%|████████▌ | 189/222 [00:10<00:02, 12.30it/s]
# left line
# y = [-0.76935953]x + 676
# right line
# y = [ 0.5920074]x + 18
# done
# left line
# y = [-0.75294673]x + 668
# right line
# y = [ 0.57506734]x + 27
# done
# left line
# y = [-0.78141141]x + 676
# right line
# y = [ 0.60820824]x + 4
# done
#  86%|████████▌ | 191/222 [00:11<00:03, 10.22it/s]
# left line
# y = [-0.77523953]x + 676
# right line
# y = [ 0.5348748]x + 48
# done
# left line
# y = [-0.79769951]x + 688
# right line
# y = [ 0.59082377]x + 15
# done
# left line
# y = [-0.81200403]x + 697
# right line
# y = [ 0.56787807]x + 33
# done
#  87%|████████▋ | 193/222 [00:11<00:02, 10.58it/s]
# left line
# y = [-0.78576809]x + 685
# right line
# y = [ 0.62332296]x + -3
# done
# left line
# y = [-0.75676817]x + 673
# right line
# y = [ 0.55355054]x + 41
# done
#  88%|████████▊ | 195/222 [00:11<00:03,  8.73it/s]
#  89%|████████▊ | 197/222 [00:11<00:02, 10.19it/s]
# left line
# y = [-0.79549617]x + 689
# right line
# y = [ 0.58509415]x + 25
# done
# left line
# y = [-0.79526091]x + 688
# right line
# y = [ 0.56550902]x + 34
# done
# left line
# y = [-0.76265478]x + 674
# right line
# y = [ 0.59248531]x + 20
# done
# left line
#  90%|████████▉ | 199/222 [00:11<00:02, 10.87it/s]
# y = [-0.82605636]x + 699
# right line
# y = [ 0.58400953]x + 24
# done
# left line
# y = [-0.77332413]x + 680
# right line
# y = [ 0.59031522]x + 22
# done
# left line
# y = [-0.81443387]x + 695
# right line
# y = [ 0.58572721]x + 23
# done
#  91%|█████████ | 201/222 [00:11<00:01, 11.09it/s]
#  91%|█████████▏| 203/222 [00:12<00:01, 12.39it/s]
# left line
# y = [-0.82727635]x + 700
# right line
# y = [ 0.59070235]x + 21
# done
# left line
# y = [-0.7750001]x + 680
# right line
# y = [ 0.60433531]x + 8
# done
# left line
# y = [-0.75368804]x + 669
# right line
# y = [ 0.59263194]x + 18
# done
#  92%|█████████▏| 205/222 [00:12<00:01, 12.29it/s]
#  93%|█████████▎| 207/222 [00:12<00:01, 13.46it/s]
# left line
# y = [-0.81203008]x + 694
# right line
# y = [ 0.5760119]x + 29
# done
# left line
# y = [-0.77570087]x + 680
# right line
# y = [ 0.57110554]x + 29
# done
# left line
# y = [-0.83406115]x + 702
# right line
# y = [ 0.571006]x + 29
# done
# left line
# y = [-0.8262406]x + 695
# right line
# y = [ 0.5623312]x + 33
# done
# left line
# y = [-0.80098039]x + 688
# right line
# y = [ 0.56633693]x + 32
#  95%|█████████▍| 210/222 [00:12<00:00, 14.72it/s]
# done
# left line
# y = [-0.73741138]x + 663
# right line
# y = [ 0.57194906]x + 28
# done
# left line
# y = [-0.7460072]x + 667
# right line
# y = [ 0.56987464]x + 30
# done
# left line
# y = [-0.75775093]x + 672
# right line
# y = [ 0.57162124]x + 30
# done
# left line
# y = [-0.77409601]x + 679
# right line
# y = [ 0.57425046]x + 30
# done
#  96%|█████████▌| 213/222 [00:12<00:00, 15.94it/s]
#  97%|█████████▋| 215/222 [00:12<00:00, 15.91it/s]
# left line
# y = [-0.79067218]x + 687
# right line
# y = [ 0.57119763]x + 32
# done
# left line
# y = [-0.75683457]x + 673
# right line
# y = [ 0.56859285]x + 33
# done
# left line
# y = [-0.80393046]x + 690
# right line
# y = [ 0.57218921]x + 32
# done
# left line
# y = [-0.74429333]x + 667
# right line
# y = [ 0.57142204]x + 33
# done
#  98%|█████████▊| 217/222 [00:12<00:00, 14.34it/s]
#  99%|█████████▉| 220/222 [00:13<00:00, 15.91it/s]
# 100%|█████████▉| 221/222 [00:13<00:00, 16.72it/s]
# left line
# y = [-0.82155234]x + 699
# right line
# y = [ 0.57084703]x + 33
# done
# left line
# y = [-0.75101095]x + 669
# right line
# y = [ 0.58071375]x + 27
# done
# left line
# y = [-0.75029737]x + 669
# right line
# y = [ 0.5460608]x + 49
# done
# left line
# y = [-0.79399467]x + 686
# right line
# y = [ 0.63679612]x + -11
# done
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidWhiteRight.mp4
#
# CPU times: user 5.69 s, sys: 820 ms, total: 6.51 s
# Wall time: 14.8 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidWhiteRight.mp4">
# </video>

# %% [markdown]
# ## Improve the draw_lines() function
#
# **At this point, if you were successful with making the pipeline and tuning parameters, you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform. As mentioned previously, try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines. You can see an example of the result you're going for in the video "P1_example.mp4".**
#
# **Go back and modify your draw_lines function accordingly and try re-running your pipeline. The new output should draw a single, solid line over the left lane line and a single, solid line over the right lane line. The lines should start from the bottom of the image and extend out to the top of the region of interest.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'test_videos_output/solidYellowLeft.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4').subclip(0,5)
clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)
# Out:
# left line
# y = [-0.606695]x + 605
# right line
# y = [ 0.68482834]x + -29
# done
# [MoviePy] >>>> Building video test_videos_output/solidYellowLeft.mp4
# [MoviePy] Writing video test_videos_output/solidYellowLeft.mp4
#   0%|          | 0/682 [00:00<?, ?it/s]
#   0%|          | 3/682 [00:00<00:24, 28.28it/s]
# left line
# y = [-0.606695]x + 605
# right line
# y = [ 0.68482834]x + -29
# done
# left line
# y = [-0.60899538]x + 606
# right line
# y = [ 0.70984989]x + -44
# done
# left line
# y = [-0.66025656]x + 625
# right line
# y = [ 0.7002514]x + -38
# done
# left line
# y = [-0.64272785]x + 619
# right line
# y = [ 0.69152206]x + -33
# done
# left line
# y = [-0.6414187]x + 621
# right line
# y = [ 0.68982524]x + -31
# done
#   1%|          | 6/682 [00:00<00:23, 28.41it/s]
# left line
# y = [-0.64142376]x + 622
# right line
# y = [ 0.73208803]x + -56
# done
#   1%|▏         | 9/682 [00:00<00:23, 28.19it/s]
# left line
# y = [-0.63723308]x + 620
# right line
# y = [ 0.70580536]x + -41
# done
# left line
# y = [-0.6332866]x + 619
# right line
# y = [ 0.71292841]x + -45
# done
# left line
# y = [-0.63352472]x + 617
# right line
# y = [ 0.73413998]x + -62
# done
# left line
# y = [-0.6535753]x + 624
# right line
# y = [ 0.66523093]x + -21
# done
# left line
# y = [-0.67704672]x + 633
# right line
# y = [ 0.67958713]x + -29
# done
#   2%|▏         | 12/682 [00:00<00:23, 28.22it/s]
# left line
# y = [-0.67049932]x + 631
# right line
# y = [ 0.69014204]x + -38
# done
#   2%|▏         | 15/682 [00:00<00:25, 26.63it/s]
# left line
# y = [-0.66821587]x + 631
# right line
# y = [ 0.65129375]x + -11
# done
# left line
# y = [-0.68090552]x + 634
# right line
# y = [ 0.68925959]x + -39
# done
# left line
# y = [-0.64086622]x + 621
# right line
# y = [ 0.64388591]x + -9
# done
# left line
# y = [-0.69152355]x + 639
# right line
# y = [ 0.64963841]x + -13
# done
# left line
# y = [-0.69636619]x + 645
# right line
# y = [ 0.65461338]x + -17
# done
# left line
# y = [-0.69207996]x + 641
# right line
# y = [ 0.70781195]x + -43
# done
#   3%|▎         | 18/682 [00:00<00:25, 26.06it/s]
#   3%|▎         | 21/682 [00:00<00:24, 27.07it/s]
# left line
# y = [-0.68708915]x + 638
# right line
# y = [ 0.69882607]x + -40
# done
# left line
# y = [-0.68538874]x + 636
# right line
# y = [ 0.66457921]x + -21
# done
# left line
# y = [-0.68999183]x + 639
# right line
# y = [ 0.66573191]x + -22
# done
# left line
# y = [-0.68831187]x + 637
# right line
# y = [ 0.65107858]x + -15
# done
# left line
# y = [-0.70484674]x + 641
# right line
# y = [ 0.63363785]x + -3
# done
# left line
# y = [-0.69622892]x + 639
# right line
# y = [ 0.67952293]x + -33
# done
# left line
# y = [-0.69698006]x + 642
# right line
# y = [ 0.67649049]x + -32
# done
#   4%|▎         | 25/682 [00:00<00:23, 28.22it/s]
#   4%|▍         | 28/682 [00:01<00:23, 28.27it/s]
# left line
# y = [-0.70286572]x + 648
# right line
# y = [ 0.68564039]x + -38
# done
# left line
# y = [-0.6930297]x + 642
# right line
# y = [ 0.66043508]x + -22
# done
# left line
# y = [-0.69596469]x + 643
# right line
# y = [ 0.65615803]x + -22
# done
# left line
# y = [-0.70056015]x + 644
# right line
# y = [ 0.66319972]x + -26
# done
# left line
# y = [-0.70654666]x + 645
# right line
# y = [ 0.68287235]x + -34
# done
# left line
# y = [-0.70775706]x + 647
# right line
# y = [ 0.70682347]x + -49
# done
# left line
# y = [-0.71921575]x + 646
# right line
# y = [ 0.70749605]x + -50
# done
#   5%|▍         | 32/682 [00:01<00:22, 28.71it/s]
# left line
# y = [-0.72816926]x + 648
# right line
# y = [ 0.63540637]x + -8
# done
# left line
# y = [-0.74531466]x + 659
# right line
# y = [ 0.66606748]x + -26
# done
# left line
# y = [-0.82980436]x + 691
# right line
# y = [ 0.69427603]x + -42
# done
#   5%|▌         | 36/682 [00:01<00:21, 29.41it/s]
# left line
# y = [-0.82706118]x + 690
# right line
# y = [ 0.64934814]x + -19
# done
# left line
# y = [-0.73853791]x + 655
# right line
# y = [ 0.66022354]x + -26
# done
# left line
# y = [-0.73871094]x + 657
# right line
# y = [ 0.65281212]x + -21
# done
# left line
# y = [-0.74619555]x + 658
# right line
# y = [ 0.65538633]x + -22
# done
#   6%|▌         | 40/682 [00:01<00:21, 30.31it/s]
# left line
# y = [-0.76533502]x + 664
# right line
# y = [ 0.65729904]x + -24
# done
# left line
# y = [-0.74209881]x + 654
# right line
# y = [ 0.65589106]x + -24
# done
# left line
# y = [-0.72686946]x + 651
# right line
# y = [ 0.63246244]x + -5
# done
#   6%|▋         | 44/682 [00:01<00:21, 29.80it/s]
# left line
# y = [-0.72426653]x + 650
# right line
# y = [ 0.65714461]x + -20
# done
# left line
# y = [-0.77750605]x + 668
# right line
# y = [ 0.65116024]x + -17
# done
# left line
# y = [-0.75784653]x + 664
# right line
# y = [ 0.65950936]x + -20
# done
# left line
# y = [-0.76366395]x + 665
# right line
# y = [ 0.66132826]x + -21
# done
# left line
# y = [-0.74282569]x + 656
# right line
# y = [ 0.64978147]x + -14
# done
#   7%|▋         | 47/682 [00:01<00:28, 22.58it/s]
# left line
# y = [-0.74632424]x + 657
# right line
# y = [ 0.63911247]x + -7
# done
#   7%|▋         | 50/682 [00:01<00:27, 22.78it/s]
# left line
# y = [-0.73391962]x + 651
# right line
# y = [ 0.66694188]x + -27
# done
# left line
# y = [-0.76487362]x + 664
# right line
# y = [ 0.64285761]x + -13
# done
# left line
# y = [-0.75085521]x + 659
# right line
# y = [ 0.6475606]x + -17
# done
# left line
# y = [-0.74236077]x + 654
# right line
# y = [ 0.64317536]x + -13
# done
#   8%|▊         | 53/682 [00:01<00:27, 23.25it/s]
# left line
# y = [-0.73219538]x + 653
# right line
# y = [ 0.66867697]x + -32
# done
# left line
# y = [-0.72377354]x + 648
# right line
# y = [ 0.64525062]x + -12
#   8%|▊         | 56/682 [00:02<00:29, 21.30it/s]
# done
# left line
# y = [-0.74716216]x + 658
# right line
# y = [ 0.66940856]x + -23
# done
# left line
# y = [-0.7272715]x + 650
# right line
# y = [ 0.66380727]x + -20
# done
# left line
# y = [-0.72187811]x + 648
# right line
# y = [ 0.65090215]x + -12
# done
#   9%|▊         | 59/682 [00:02<00:30, 20.43it/s]
# left line
# y = [-0.71624821]x + 646
# right line
# y = [ 0.65836364]x + -17
# done
# left line
# y = [-0.69813001]x + 638
# right line
# y = [ 0.65566409]x + -17
# done
# left line
# y = [-0.70841324]x + 643
# right line
# y = [ 0.65126473]x + -13
# done
# left line
# y = [-0.71005696]x + 645
# right line
# y = [ 0.66039693]x + -17
# done
#   9%|▉         | 62/682 [00:02<00:32, 19.05it/s]
# left line
# y = [-0.71220052]x + 642
# right line
# y = [ 0.61826426]x + 7
# done
# left line
# y = [-0.72630501]x + 651
# right line
# y = [ 0.64513439]x + -10
# done
# left line
# y = [-0.71774036]x + 646
# right line
# y = [ 0.63102674]x + -2
# done
# left line
#  10%|▉         | 65/682 [00:02<00:30, 19.98it/s]
# y = [-0.72817099]x + 652
# right line
# y = [ 0.63773638]x + -6
# done
# left line
# y = [-0.75359619]x + 660
# right line
# y = [ 0.63725156]x + -8
# done
#  10%|▉         | 68/682 [00:02<00:32, 19.02it/s]
# left line
# y = [-0.70275319]x + 641
# right line
# y = [ 0.66964197]x + -21
# done
# left line
# y = [-0.71547514]x + 647
# right line
# y = [ 0.65826637]x + -15
# done
# left line
# y = [-0.69582272]x + 641
# right line
# y = [ 0.66406763]x + -19
# done
# left line
# y = [-0.72511131]x + 653
# right line
# y = [ 0.67219055]x + -22
# done
#  10%|█         | 70/682 [00:02<00:34, 17.53it/s]
# left line
# y = [-0.72433496]x + 650
# right line
# y = [ 0.6623975]x + -17
# done
# left line
#  11%|█         | 72/682 [00:03<00:34, 17.75it/s]
#  11%|█         | 74/682 [00:03<00:34, 17.67it/s]
# y = [-0.69710207]x + 640
# right line
# y = [ 0.72187936]x + -54
# done
# left line
# y = [-0.71680307]x + 646
# right line
# y = [ 0.66022462]x + -15
# done
# left line
# y = [-0.72657877]x + 653
# right line
# y = [ 0.64975071]x + -9
# done
# left line
# y = [-0.70758832]x + 645
# right line
# y = [ 0.63224918]x + 0
# done
#  11%|█         | 76/682 [00:03<00:35, 17.25it/s]
# left line
# y = [-0.71676999]x + 647
# right line
# y = [ 0.65142345]x + -11
# done
# left line
# y = [-0.70246917]x + 640
# right line
# y = [ 0.64711428]x + -7
# done
# left line
# y = [-0.72721702]x + 653
# right line
# y = [ 0.62831181]x + 6
# done
#  11%|█▏        | 78/682 [00:03<00:46, 13.11it/s]
# left line
# y = [-0.71849138]x + 648
# right line
# y = [ 0.6529572]x + -11
# done
# left line
# y = [-0.72646689]x + 653
#  12%|█▏        | 80/682 [00:03<00:43, 13.93it/s]
# right line
# y = [ 0.6477648]x + -8
# done
# left line
# y = [-0.71681064]x + 647
# right line
# y = [ 0.67563295]x + -22
# done
# left line
# y = [-0.71615964]x + 644
# right line
# y = [ 0.66312104]x + -17
# done
# left line
# y = [-0.72039396]x + 648
# right line
#  12%|█▏        | 83/682 [00:03<00:39, 15.34it/s]
# y = [ 0.65762591]x + -14
# done
# left line
# y = [-0.72575539]x + 651
#  13%|█▎        | 86/682 [00:03<00:36, 16.34it/s]
# right line
# y = [ 0.67168224]x + -21
# done
# left line
# y = [-0.71009558]x + 643
# right line
# y = [ 0.66645324]x + -17
# done
# left line
# y = [-0.6961177]x + 635
# right line
# y = [ 0.65427417]x + -10
# done
# left line
# y = [-0.69302022]x + 636
# right line
# y = [ 0.65760428]x + -13
# done
#  13%|█▎        | 88/682 [00:04<00:41, 14.16it/s]
# left line
# y = [-0.6742577]x + 626
# right line
# y = [ 0.62846196]x + 3
# done
# left line
# y = [-0.67294163]x + 628
# right line
# y = [ 0.65295058]x + -12
# done
# left line
# y = [-0.68566293]x + 634
# right line
# y = [ 0.6384846]x + -3
# done
#  13%|█▎        | 90/682 [00:04<00:45, 13.04it/s]
# left line
# y = [-0.70587397]x + 642
# right line
# y = [ 0.64461899]x + -4
# done
#  13%|█▎        | 92/682 [00:04<00:42, 13.85it/s]
# left line
# y = [-0.69204432]x + 639
# right line
# y = [ 0.63727093]x + 0
# done
# left line
# y = [-0.68466294]x + 637
# right line
# y = [ 0.63853317]x + 1
# done
# left line
# y = [-0.69838119]x + 644
# right line
# y = [ 0.65442425]x + -7
# done
#  14%|█▍        | 94/682 [00:04<00:41, 14.14it/s]
# left line
# y = [-0.70497972]x + 648
# right line
# y = [ 0.67910945]x + -21
# done
#  14%|█▍        | 96/682 [00:04<00:40, 14.55it/s]
# left line
# y = [-0.67771739]x + 635
# right line
# y = [ 0.66040152]x + -10
# done
# left line
# y = [-0.68163955]x + 636
# right line
# y = [ 0.64750844]x + -4
# done
# left line
# y = [-0.68450546]x + 636
# right line
# y = [ 0.66930139]x + -16
# done
#  14%|█▍        | 98/682 [00:04<00:38, 15.17it/s]
# left line
# y = [-0.67373723]x + 632
# right line
# y = [ 0.66834301]x + -17
# done
#  15%|█▍        | 100/682 [00:04<00:37, 15.58it/s]
# left line
# y = [-0.67627174]x + 633
# right line
# y = [ 0.63942754]x + -2
# done
# left line
# y = [-0.67774177]x + 634
# right line
# y = [ 0.67102706]x + -20
# done
#  15%|█▍        | 102/682 [00:05<00:41, 14.11it/s]
# left line
# y = [-0.68798888]x + 639
# right line
# y = [ 0.6543166]x + -10
# done
#  15%|█▌        | 104/682 [00:05<00:41, 14.08it/s]
# left line
# y = [-0.67973149]x + 634
# right line
# y = [ 0.65354729]x + -10
# done
# left line
# y = [-0.70183539]x + 646
# right line
# y = [ 0.64003789]x + -3
# done
# left line
# y = [-0.685956]x + 637
# right line
# y = [ 0.63995779]x + 0
# done
#  16%|█▌        | 106/682 [00:05<00:44, 13.04it/s]
# left line
# y = [-0.69348854]x + 639
# right line
# y = [ 0.66232681]x + -14
# done
# left line
# y = [-0.69744474]x + 641
# right line
# y = [ 0.67314452]x + -21
# done
# left line
# y = [-0.70437431]x + 644
# right line
# y = [ 0.70166129]x + -35
# done
# left line
# y = [-0.69706285]x + 642
# right line
# y = [ 0.65823734]x + -11
# done
#  16%|█▌        | 109/682 [00:05<00:39, 14.43it/s]
#  16%|█▋        | 111/682 [00:05<00:37, 15.43it/s]
# left line
# y = [-0.70210803]x + 643
# right line
# y = [ 0.63848311]x + 0
# done
# left line
# y = [-0.68870389]x + 639
# right line
# y = [ 0.67811447]x + -23
# done
# left line
# y = [-0.69109434]x + 640
# right line
# y = [ 0.67704147]x + -21
# done
# left line
# y = [-0.68547475]x + 637
# right line
# y = [ 0.65356314]x + -10
# done
#  17%|█▋        | 113/682 [00:05<00:39, 14.26it/s]
# left line
# y = [-0.69845921]x + 643
# right line
# y = [ 0.64163166]x + -3
# done
#  17%|█▋        | 116/682 [00:06<00:38, 14.58it/s]
# left line
# y = [-0.69435388]x + 640
# right line
# y = [ 0.62508297]x + 6
# done
# left line
# y = [-0.67663705]x + 635
# right line
# y = [ 0.63976872]x + -2
# done
# left line
# y = [-0.68976933]x + 636
# right line
# y = [ 0.63821149]x + -2
# done
# left line
# y = [-0.67748296]x + 631
# right line
# y = [ 0.60462898]x + 25
# done
#  17%|█▋        | 118/682 [00:06<00:39, 14.28it/s]
#  18%|█▊        | 120/682 [00:06<00:36, 15.58it/s]
# left line
# y = [-0.68438053]x + 635
# right line
# y = [ 0.66576588]x + -16
# done
# left line
# y = [-0.71877116]x + 651
# right line
# y = [ 0.63629729]x + 0
# done
# left line
# y = [-0.72344279]x + 655
# right line
# y = [ 0.62894309]x + 2
# done
# left line
# y = [-0.72505856]x + 653
# right line
# y = [ 0.59855437]x + 19
# done
#  18%|█▊        | 122/682 [00:06<00:37, 14.89it/s]
# left line
# y = [-0.72074765]x + 651
# right line
# y = [ 0.61164415]x + 14
# done
# left line
#  18%|█▊        | 125/682 [00:06<00:34, 16.26it/s]
# y = [-0.7080344]x + 646
# right line
# y = [ 0.55933678]x + 43
# done
# left line
# y = [-0.71446538]x + 649
# right line
# y = [ 0.63735384]x + -2
# done
# left line
# y = [-0.72180218]x + 653
# right line
# y = [ 0.62483895]x + 5
# done
#  19%|█▊        | 127/682 [00:06<00:43, 12.89it/s]
# left line
# y = [-0.71893883]x + 652
# right line
# y = [ 0.64096689]x + -3
# done
# left line
# y = [-0.72609353]x + 658
# right line
# y = [ 0.63186514]x + 3
# done
# left line
# y = [-0.71395606]x + 651
# right line
# y = [ 0.644584]x + -5
# done
#  19%|█▉        | 129/682 [00:07<00:48, 11.44it/s]
# left line
# y = [-0.70501435]x + 648
# right line
# y = [ 0.63673812]x + 0
# done
# left line
# y = [-0.69947845]x + 645
# right line
# y = [ 0.69285423]x + -34
# done
#  19%|█▉        | 131/682 [00:07<00:54, 10.15it/s]
#  20%|█▉        | 133/682 [00:07<00:47, 11.52it/s]
#  20%|█▉        | 135/682 [00:07<00:41, 13.13it/s]
# left line
# y = [-0.70028055]x + 643
# right line
# y = [ 0.63468891]x + 1
# done
# left line
# y = [-0.70206088]x + 644
# right line
# y = [ 0.55473554]x + 42
# done
# left line
# y = [-0.70222771]x + 647
# right line
# y = [ 0.63021249]x + 3
# done
# left line
# y = [-0.69903016]x + 645
# right line
# y = [ 0.6118561]x + 12
# done
# left line
#  20%|██        | 137/682 [00:07<00:37, 14.35it/s]
#  20%|██        | 139/682 [00:07<00:35, 15.27it/s]
# y = [-0.68122774]x + 638
# right line
# y = [ 0.63623965]x + 0
# done
# left line
# y = [-0.71040547]x + 650
# right line
# y = [ 0.63965803]x + 0
# done
# left line
# y = [-0.71341759]x + 651
# right line
# y = [ 0.58055168]x + 34
# done
# left line
# y = [-0.71070868]x + 650
# right line
# y = [ 0.62710142]x + 6
# done
# left line
# y = [-0.72607785]x + 654
# right line
# y = [ 0.62836522]x + 3
# done
#  21%|██        | 141/682 [00:07<00:37, 14.48it/s]
# left line
# y = [-0.72254544]x + 653
# right line
# y = [ 0.63029224]x + 5
# done
# left line
# y = [-0.70949614]x + 649
# right line
# y = [ 0.62347502]x + 8
# done
# left line
# y = [-0.71933091]x + 653
# right line
# y = [ 0.6205318]x + 8
# done
#  21%|██        | 143/682 [00:08<00:44, 12.12it/s]
#  21%|██▏       | 145/682 [00:08<00:44, 12.02it/s]
# left line
# y = [-0.71659583]x + 650
# right line
# y = [ 0.6136173]x + 13
# done
# left line
# y = [-0.71421111]x + 649
# right line
# y = [ 0.53267241]x + 55
# done
# left line
# y = [-0.72428149]x + 657
# right line
# y = [ 0.60519278]x + 18
# done
#  22%|██▏       | 147/682 [00:08<00:48, 11.04it/s]
#  22%|██▏       | 150/682 [00:08<00:40, 13.00it/s]
# left line
# y = [-0.71452761]x + 650
# right line
# y = [ 0.62299573]x + 8
# done
# left line
# y = [-0.7068066]x + 648
# right line
# y = [ 0.62450296]x + 3
# done
# left line
# y = [-0.72181755]x + 654
# right line
# y = [ 0.58411896]x + 30
# done
# left line
# y = [-0.69806761]x + 643
# right line
# y = [ 0.62972581]x + 5
# done
# left line
# y = [-0.69168603]x + 641
# right line
# y = [ 0.60235304]x + 20
# done
#  22%|██▏       | 152/682 [00:08<00:38, 13.83it/s]
# left line
# y = [-0.70354557]x + 648
# right line
# y = [ 0.58973944]x + 28
# done
# left line
# y = [-0.6946308]x + 644
# right line
# y = [ 0.61876738]x + 9
# done
# left line
# y = [-0.70143861]x + 646
# right line
# y = [ 0.60824019]x + 18
# done
#  23%|██▎       | 154/682 [00:08<00:41, 12.84it/s]
#  23%|██▎       | 156/682 [00:09<00:40, 12.99it/s]
# left line
# y = [-0.68146491]x + 640
# right line
# y = [ 0.60021907]x + 25
# done
# left line
# y = [-0.68047255]x + 640
# right line
# y = [ 0.53433317]x + 56
# done
# left line
# y = [-0.68112332]x + 642
# right line
# y = [ 0.42688602]x + 110
# done
# left line
# y = [-0.6951375]x + 648
# right line
# y = [ 0.55646062]x + 45
# done
#  23%|██▎       | 158/682 [00:09<00:41, 12.68it/s]
#  24%|██▎       | 161/682 [00:09<00:35, 14.51it/s]
# left line
# y = [-0.69804764]x + 650
# right line
# y = [ 0.59641671]x + 25
# done
# left line
# y = [-0.6904282]x + 649
# right line
# y = [ 0.51377773]x + 77
# done
# left line
# y = [-0.70538992]x + 654
# right line
# y = [ 0.58979458]x + 29
# done
# left line
# y = [-0.69866884]x + 651
# right line
# y = [ 0.58452332]x + 31
# done
#  24%|██▍       | 163/682 [00:09<00:36, 14.34it/s]
#  24%|██▍       | 166/682 [00:09<00:33, 15.45it/s]
# left line
# y = [-0.70960826]x + 657
# right line
# y = [ 0.57602412]x + 35
# done
# left line
# y = [-0.72070879]x + 659
# right line
# y = [ 0.58266735]x + 30
# done
# left line
# y = [-0.72669798]x + 666
# right line
# y = [ 0.59595942]x + 23
# done
# left line
# y = [-0.71925712]x + 659
# right line
# y = [ 0.60616815]x + 16
# done
#  25%|██▍       | 168/682 [00:09<00:33, 15.47it/s]
# left line
# y = [-0.71582425]x + 657
# right line
# y = [ 0.60675156]x + 16
# done
# left line
# y = [-0.68519306]x + 644
# right line
# y = [ 0.59444737]x + 25
# done
# left line
# y = [-0.71270436]x + 658
# right line
# y = [ 0.56510663]x + 39
# done
#  25%|██▍       | 170/682 [00:10<00:38, 13.46it/s]
#  25%|██▌       | 172/682 [00:10<00:35, 14.33it/s]
# left line
# y = [-0.71186072]x + 656
# right line
# y = [ 0.57042176]x + 35
# done
# left line
# y = [-0.7172606]x + 659
# right line
# y = [ 0.58273876]x + 29
# done
# left line
# y = [-0.71901703]x + 660
# right line
# y = [ 0.57882118]x + 31
# done
# left line
# y = [-0.71561497]x + 659
# right line
# y = [ 0.54928678]x + 49
# done
# left line
#  26%|██▌       | 175/682 [00:10<00:32, 15.38it/s]
# y = [-0.74540037]x + 671
# right line
# y = [ 0.57661659]x + 31
# done
# left line
# y = [-0.74659681]x + 670
# right line
# y = [ 0.57604212]x + 31
# done
# left line
# y = [-0.7325514]x + 664
# right line
# y = [ 0.5638566]x + 39
# done
# left line
# y = [-0.73342061]x + 666
# right line
# y = [ 0.57739377]x + 32
# done
#  26%|██▌       | 178/682 [00:10<00:32, 15.56it/s]
#  26%|██▋       | 180/682 [00:10<00:31, 15.98it/s]
# left line
# y = [-0.72694439]x + 664
# right line
# y = [ 0.58275068]x + 29
# done
# left line
# y = [-0.7473833]x + 674
# right line
# y = [ 0.56441629]x + 38
# done
# left line
# y = [-0.7582795]x + 677
# right line
# y = [ 0.56052059]x + 41
# done
#  27%|██▋       | 182/682 [00:10<00:35, 14.13it/s]
# left line
# y = [-0.77966446]x + 685
# right line
# y = [ 0.52281284]x + 59
# done
# left line
# y = [-0.76045394]x + 677
# right line
# y = [ 0.52870393]x + 58
# done
# left line
# y = [-0.77389717]x + 681
# right line
# y = [ 0.51115775]x + 66
# done
#  27%|██▋       | 184/682 [00:10<00:32, 15.22it/s]
#  27%|██▋       | 186/682 [00:11<00:31, 15.82it/s]
# left line
# y = [-0.76398367]x + 679
# right line
# y = [ 0.56583941]x + 38
# done
# left line
# y = [-0.7704922]x + 680
# right line
# y = [ 0.53548563]x + 55
# done
# left line
# y = [-0.77189332]x + 682
# right line
# y = [ 0.55485678]x + 46
# done
# left line
# y = [-0.7823239]x + 688
# right line
# y = [ 0.55425078]x + 46
# done
#  28%|██▊       | 189/682 [00:11<00:29, 16.65it/s]
# left line
# y = [-0.76768684]x + 681
# right line
# y = [ 0.56161314]x + 42
# done
# left line
# y = [-0.74570054]x + 671
# right line
# y = [ 0.56243533]x + 42
# done
# left line
# y = [-0.75564229]x + 673
# right line
# y = [ 0.55660027]x + 45
# done
# left line
# y = [-0.75293767]x + 669
# right line
# y = [ 0.56039482]x + 44
# done
#  28%|██▊       | 192/682 [00:11<00:28, 17.21it/s]
#  29%|██▊       | 195/682 [00:11<00:26, 18.53it/s]
# left line
# y = [-0.7793175]x + 681
# right line
# y = [ 0.50515634]x + 72
# done
# left line
# y = [-0.76711887]x + 677
# right line
# y = [ 0.55083746]x + 49
# done
# left line
# y = [-0.7567994]x + 673
# right line
# y = [ 0.55198061]x + 47
# done
# left line
# y = [-0.76787961]x + 677
# right line
# y = [ 0.48366871]x + 81
# done
# left line
# y = [-0.7710349]x + 677
# right line
# y = [ 0.52898389]x + 58
# done
#  29%|██▉       | 197/682 [00:11<00:27, 17.38it/s]
#  29%|██▉       | 200/682 [00:11<00:27, 17.73it/s]
# left line
# y = [-0.7508359]x + 666
# right line
# y = [ 0.49966598]x + 75
# done
# left line
# y = [-0.76805806]x + 677
# right line
# y = [ 0.48386845]x + 82
# done
# left line
# y = [-0.74314415]x + 666
# right line
# y = [ 0.54950213]x + 49
# done
# left line
# y = [-0.76308948]x + 673
# right line
# y = [ 0.52437681]x + 64
# done
#  30%|██▉       | 202/682 [00:11<00:27, 17.24it/s]
# left line
# y = [-0.77023059]x + 675
# right line
# y = [ 0.57076609]x + 39
# done
# left line
# y = [-0.76621348]x + 674
# right line
# y = [ 0.56461775]x + 42
# done
# left line
# y = [-0.77326167]x + 676
# right line
# y = [ 0.5988993]x + 20
# done
# left line
# y = [-0.74848974]x + 667
# right line
# y = [ 0.5537681]x + 49
# done
#  30%|███       | 205/682 [00:12<00:25, 18.84it/s]
#  30%|███       | 207/682 [00:12<00:26, 17.94it/s]
# left line
# y = [-0.760369]x + 671
# right line
# y = [ 0.58883369]x + 30
# done
# left line
# y = [-0.73161131]x + 662
# right line
# y = [ 0.4686771]x + 93
# done
# left line
# y = [-0.74346817]x + 665
# right line
# y = [ 0.54758555]x + 54
# done
# left line
# y = [-0.73392349]x + 662
# right line
# y = [ 0.5650422]x + 38
# done
#  31%|███       | 210/682 [00:12<00:27, 17.44it/s]
# left line
# y = [-0.73621136]x + 664
# right line
# y = [ 0.5521878]x + 51
# done
# left line
# y = [-0.73673952]x + 662
# right line
# y = [ 0.56668234]x + 43
# done
# left line
# y = [-0.73987979]x + 665
# right line
# y = [ 0.54344207]x + 57
# done
# left line
# y = [-0.72565132]x + 657
# right line
# y = [ 0.57816237]x + 37
# done
# left line
# y = [-0.74872661]x + 668
# right line
# y = [ 0.58406264]x + 34
# done
#  31%|███       | 213/682 [00:12<00:24, 18.85it/s]
#  32%|███▏      | 215/682 [00:12<00:30, 15.33it/s]
# left line
# y = [-0.74338394]x + 666
# right line
# y = [ 0.59095556]x + 28
# done
# left line
# y = [-0.75790656]x + 671
# right line
# y = [ 0.58790922]x + 32
# done
#  32%|███▏      | 218/682 [00:12<00:28, 16.37it/s]
# left line
# y = [-0.73599386]x + 662
# right line
# y = [ 0.58795524]x + 32
# done
# left line
# y = [-0.72055429]x + 654
# right line
# y = [ 0.58782071]x + 33
# done
# left line
# y = [-0.73562819]x + 661
# right line
# y = [ 0.60503125]x + 23
# done
# left line
# y = [-0.72659677]x + 658
# right line
# y = [ 0.56994784]x + 41
# done
# left line
# y = [-0.71249974]x + 651
# right line
# y = [ 0.53555542]x + 56
# done
#  32%|███▏      | 220/682 [00:12<00:26, 17.20it/s]
#  33%|███▎      | 223/682 [00:13<00:26, 17.62it/s]
# left line
# y = [-0.74307895]x + 661
# right line
# y = [ 0.57460433]x + 38
# done
# left line
# y = [-0.72452116]x + 652
# right line
# y = [ 0.54444313]x + 53
# done
# left line
# y = [-0.7132799]x + 652
# right line
# y = [ 0.57724017]x + 36
# done
# left line
# y = [-0.72199374]x + 653
# right line
# y = [ 0.55764908]x + 47
# done
# left line
# y = [-0.73312914]x + 660
# right line
# y = [ 0.58785927]x + 32
# done
#  33%|███▎      | 226/682 [00:13<00:26, 17.22it/s]
# left line
# y = [-0.72555906]x + 656
# right line
# y = [ 0.58332562]x + 34
# done
# left line
# y = [-0.73052275]x + 658
# right line
# y = [ 0.59227759]x + 28
# done
# left line
# y = [-0.72842783]x + 658
#  33%|███▎      | 228/682 [00:13<00:26, 17.01it/s]
#  34%|███▎      | 230/682 [00:13<00:27, 16.49it/s]
# right line
# y = [ 0.61897159]x + 7
# done
# left line
# y = [-0.72050965]x + 653
# right line
# y = [ 0.59197527]x + 27
# done
# left line
# y = [-0.70303327]x + 646
# right line
# y = [ 0.60378104]x + 21
# done
# left line
# y = [-0.71110731]x + 650
# right line
# y = [ 0.60828096]x + 16
# done
#  34%|███▍      | 233/682 [00:13<00:25, 17.87it/s]
#  34%|███▍      | 235/682 [00:13<00:25, 17.50it/s]
# left line
# y = [-0.72373813]x + 655
# right line
# y = [ 0.49155408]x + 76
# done
# left line
# y = [-0.71883363]x + 653
# right line
# y = [ 0.58699435]x + 30
# done
# left line
# y = [-0.72376466]x + 655
# right line
# y = [ 0.61444473]x + 17
# done
# left line
# y = [-0.72007757]x + 654
# right line
# y = [ 0.60060108]x + 20
# done
#  35%|███▍      | 238/682 [00:13<00:24, 18.18it/s]
# left line
# y = [-0.72777003]x + 657
# right line
# y = [ 0.57768619]x + 33
# done
# left line
# y = [-0.71723551]x + 651
# right line
# y = [ 0.58691263]x + 28
# done
# left line
# y = [-0.72518283]x + 655
# right line
# y = [ 0.59829509]x + 23
# done
# left line
# y = [-0.71803266]x + 651
# right line
# y = [ 0.59526485]x + 23
# done
#  35%|███▌      | 241/682 [00:14<00:22, 19.50it/s]
# left line
# y = [-0.71238256]x + 650
# right line
# y = [ 0.6003539]x + 22
# done
# left line
# y = [-0.72804886]x + 658
# right line
# y = [ 0.58995241]x + 28
# done
# left line
# y = [-0.72365797]x + 655
# right line
# y = [ 0.58504176]x + 30
# done
# left line
# y = [-0.71518278]x + 652
# right line
# y = [ 0.59357178]x + 26
# done
# left line
#  36%|███▌      | 244/682 [00:14<00:23, 18.47it/s]
#  36%|███▌      | 246/682 [00:14<00:26, 16.58it/s]
# y = [-0.70520467]x + 649
# right line
# y = [ 0.58360654]x + 32
# done
# left line
# y = [-0.69885242]x + 645
# right line
# y = [ 0.46267661]x + 93
# done
# left line
# y = [-0.70394063]x + 649
# right line
# y = [ 0.5657292]x + 44
# done
#  36%|███▋      | 248/682 [00:14<00:26, 16.59it/s]
# left line
# y = [-0.697631]x + 645
# right line
# y = [ 0.55588198]x + 47
# done
# left line
# y = [-0.71733636]x + 651
# right line
# y = [ 0.58058107]x + 35
# done
# left line
# y = [-0.68573833]x + 642
# right line
# y = [ 0.61502421]x + 15
# done
# left line
# y = [-0.6680963]x + 636
# right line
# y = [ 0.56628174]x + 43
# done
# left line
# y = [-0.67234528]x + 637
# right line
# y = [ 0.60544544]x + 18
# done
#  37%|███▋      | 251/682 [00:14<00:23, 18.22it/s]
#  37%|███▋      | 253/682 [00:14<00:23, 18.48it/s]
#  37%|███▋      | 255/682 [00:14<00:22, 18.82it/s]
# left line
# y = [-0.71666431]x + 651
# right line
# y = [ 0.60757124]x + 20
# done
# left line
# y = [-0.71434629]x + 649
# right line
# y = [ 0.59317893]x + 28
# done
# left line
# y = [-0.70096076]x + 644
# right line
# y = [ 0.60029334]x + 25
# done
# left line
# y = [-0.72316611]x + 652
# right line
# y = [ 0.60153443]x + 24
# done
# left line
#  38%|███▊      | 257/682 [00:14<00:22, 18.60it/s]
# y = [-0.73840094]x + 661
# right line
# y = [ 0.60148096]x + 25
# done
# left line
# y = [-0.74659789]x + 664
# right line
# y = [ 0.61390018]x + 17
# done
# left line
# y = [-0.73092693]x + 657
# right line
# y = [ 0.471688]x + 90
# done
# left line
# y = [-0.73002547]x + 658
# right line
# y = [ 0.47624385]x + 88
# done
#  38%|███▊      | 259/682 [00:15<00:23, 17.87it/s]
#  38%|███▊      | 262/682 [00:15<00:22, 18.45it/s]
# left line
# y = [-0.71159929]x + 651
# right line
# y = [ 0.48698938]x + 82
# done
# left line
# y = [-0.72384959]x + 654
# right line
# y = [ 0.58123875]x + 35
# done
# left line
# y = [-0.71603364]x + 652
# right line
# y = [ 0.51380932]x + 70
# done
# left line
# y = [-0.70015562]x + 643
# right line
# y = [ 0.49496832]x + 78
# done
#  39%|███▊      | 264/682 [00:15<00:22, 18.79it/s]
#  39%|███▉      | 267/682 [00:15<00:21, 19.42it/s]
# left line
# y = [-0.71178544]x + 650
# right line
# y = [ 0.55102772]x + 50
# done
# left line
# y = [-0.69383156]x + 643
# right line
# y = [ 0.5996151]x + 22
# done
# left line
# y = [-0.71205413]x + 650
# right line
# y = [ 0.61158586]x + 16
# done
# left line
# y = [-0.72275656]x + 655
# right line
# y = [ 0.59195805]x + 28
# done
#  39%|███▉      | 269/682 [00:15<00:21, 19.40it/s]
#  40%|███▉      | 271/682 [00:15<00:21, 19.46it/s]
# left line
# y = [-0.72338539]x + 655
# right line
# y = [ 0.59743696]x + 27
# done
# left line
# y = [-0.71929401]x + 656
# right line
# y = [ 0.56263238]x + 44
# done
# left line
# y = [-0.71416605]x + 652
# right line
# y = [ 0.41194624]x + 117
# done
# left line
# y = [-0.71090019]x + 650
# right line
# y = [ 0.50171125]x + 73
# done
#  40%|████      | 273/682 [00:15<00:21, 19.18it/s]
# left line
# y = [-0.73764747]x + 663
# right line
# y = [ 0.47809109]x + 86
# done
# left line
# y = [-0.70610118]x + 650
# right line
# y = [ 0.49717498]x + 78
# done
# left line
# y = [-0.71051872]x + 654
# right line
# y = [ 0.48700392]x + 82
# done
# left line
# y = [-0.70731902]x + 650
# right line
# y = [ 0.5165537]x + 68
# done
# left line
#  40%|████      | 276/682 [00:15<00:21, 19.30it/s]
#  41%|████      | 278/682 [00:16<00:21, 19.17it/s]
# y = [-0.70840353]x + 650
# right line
# y = [ 0.53030896]x + 60
# done
# left line
# y = [-0.71381521]x + 654
# right line
# y = [ 0.5423314]x + 54
# done
# left line
# y = [-0.71340829]x + 651
# right line
# y = [ 0.55901223]x + 45
# done
# left line
# y = [-0.70973241]x + 651
# right line
# y = [ 0.55455154]x + 48
# done
# left line
# y = [-0.7029981]x + 649
# right line
# y = [ 0.5823319]x + 35
# done
#  41%|████      | 281/682 [00:16<00:19, 20.56it/s]
#  42%|████▏     | 284/682 [00:16<00:20, 19.04it/s]
# left line
# y = [-0.72331858]x + 657
# right line
# y = [ 0.58223373]x + 35
# done
# left line
# y = [-0.71510792]x + 656
# right line
# y = [ 0.58771282]x + 33
# done
# left line
# y = [-0.71816498]x + 655
# right line
# y = [ 0.40136868]x + 125
# done
# left line
# y = [-0.71404463]x + 653
# right line
# y = [ 0.56237006]x + 47
# done
#  42%|████▏     | 286/682 [00:16<00:20, 19.25it/s]
#  42%|████▏     | 289/682 [00:16<00:19, 20.22it/s]
# left line
# y = [-0.69969851]x + 645
# right line
# y = [ 0.53745699]x + 55
# done
# left line
# y = [-0.74560523]x + 665
# right line
# y = [ 0.50256622]x + 77
# done
# left line
# y = [-0.70717359]x + 651
# right line
# y = [ 0.55552143]x + 51
# done
# left line
# y = [-0.71778345]x + 657
# right line
# y = [ 0.58930147]x + 34
# done
# left line
# y = [-0.73348427]x + 662
# right line
# y = [ 0.58005434]x + 40
# done
#  43%|████▎     | 292/682 [00:16<00:19, 20.17it/s]
# left line
# y = [-0.71340156]x + 657
# right line
# y = [ 0.62349719]x + 10
# done
# left line
# y = [-0.72593391]x + 660
# right line
# y = [ 0.56639296]x + 50
# done
# left line
# y = [-0.72259361]x + 656
# right line
# y = [ 0.5896284]x + 36
# done
# left line
# y = [-0.72513741]x + 658
# right line
# y = [ 0.58897889]x + 33
# done
#  43%|████▎     | 295/682 [00:16<00:21, 17.72it/s]
# left line
# y = [-0.70634168]x + 652
# right line
# y = [ 0.57029861]x + 43
# done
# left line
# y = [-0.71031934]x + 653
# right line
# y = [ 0.58600593]x + 34
# done
# left line
# y = [-0.72447377]x + 657
# right line
# y = [ 0.51473641]x + 70
# done
# left line
# y = [-0.70263869]x + 649
# right line
# y = [ 0.61553395]x + 17
# done
#  44%|████▎     | 298/682 [00:17<00:21, 18.19it/s]
#  44%|████▍     | 301/682 [00:17<00:18, 20.12it/s]
# left line
# y = [-0.70664316]x + 650
# right line
# y = [ 0.61150193]x + 18
# done
# left line
# y = [-0.72174799]x + 658
# right line
# y = [ 0.6046195]x + 23
# done
# left line
# y = [-0.71140206]x + 655
# right line
# y = [ 0.55664301]x + 50
# done
# left line
# y = [-0.72418106]x + 655
# right line
# y = [ 0.57000172]x + 43
# done
#  45%|████▍     | 304/682 [00:17<00:19, 18.99it/s]
# left line
# y = [-0.69648659]x + 648
# right line
# y = [ 0.60279405]x + 24
# done
# left line
# y = [-0.72883224]x + 660
# right line
# y = [ 0.5856719]x + 33
# done
# left line
# y = [-0.72251153]x + 654
# right line
# y = [ 0.6120885]x + 16
# done
# left line
# y = [-0.72289008]x + 656
# right line
# y = [ 0.61454064]x + 15
# done
#  45%|████▍     | 306/682 [00:17<00:20, 18.40it/s]
#  45%|████▌     | 308/682 [00:17<00:21, 17.02it/s]
# left line
# y = [-0.70068061]x + 643
# right line
# y = [ 0.62121308]x + 11
# done
# left line
# y = [-0.72312909]x + 653
# right line
# y = [ 0.59727681]x + 24
# done
# left line
# y = [-0.76222682]x + 669
# right line
# y = [ 0.60275507]x + 21
# done
#  45%|████▌     | 310/682 [00:17<00:24, 15.15it/s]
# left line
# y = [-0.72497261]x + 654
# right line
# y = [ 0.61182272]x + 15
# done
# left line
# y = [-0.7193206]x + 651
# right line
# y = [ 0.53552729]x + 56
# done
# left line
# y = [-0.72376931]x + 651
# right line
# y = [ 0.59317243]x + 26
# done
# left line
# y = [-0.71119899]x + 648
# right line
# y = [ 0.60151988]x + 21
# done
#  46%|████▌     | 312/682 [00:17<00:25, 14.44it/s]
#  46%|████▌     | 315/682 [00:18<00:21, 16.75it/s]
# left line
# y = [-0.71735972]x + 651
# right line
# y = [ 0.59635532]x + 26
# done
# left line
# y = [-0.72123188]x + 653
# right line
# y = [ 0.6057387]x + 19
# done
# left line
# y = [-0.72682703]x + 655
# right line
# y = [ 0.57579005]x + 38
# done
# left line
# y = [-0.72510767]x + 655
# right line
# y = [ 0.59834683]x + 25
# done
# left line
#  46%|████▋     | 317/682 [00:18<00:23, 15.48it/s]
#  47%|████▋     | 320/682 [00:18<00:21, 17.14it/s]
# y = [-0.73741633]x + 659
# right line
# y = [ 0.60070562]x + 24
# done
# left line
# y = [-0.72247684]x + 653
# right line
# y = [ 0.59747404]x + 25
# done
# left line
# y = [-0.71262121]x + 650
# right line
# y = [ 0.5985238]x + 24
# done
# left line
# y = [-0.72510475]x + 654
# right line
# y = [ 0.56446236]x + 43
# done
# left line
# y = [-0.71466297]x + 649
# right line
# y = [ 0.60065424]x + 23
# done
#  47%|████▋     | 322/682 [00:18<00:23, 15.45it/s]
# left line
# y = [-0.72018009]x + 650
# right line
# y = [ 0.59875327]x + 24
# done
# left line
# y = [-0.70924056]x + 646
# right line
# y = [ 0.60614067]x + 20
# done
# left line
# y = [-0.69485438]x + 640
# right line
# y = [ 0.57556999]x + 39
# done
# left line
# y = [-0.71361005]x + 648
# right line
# y = [ 0.59996659]x + 23
# done
#  48%|████▊     | 325/682 [00:18<00:22, 15.98it/s]
# left line
# y = [-0.71492219]x + 649
# right line
# y = [ 0.59543896]x + 27
# done
# left line
# y = [-0.70924711]x + 648
# right line
# y = [ 0.58906901]x + 32
# done
# left line
# y = [-0.7126103]x + 649
# right line
# y = [ 0.60685295]x + 21
# done
#  48%|████▊     | 328/682 [00:18<00:24, 14.47it/s]
#  49%|████▊     | 331/682 [00:19<00:21, 16.22it/s]
# left line
# y = [-0.70841604]x + 646
# right line
# y = [ 0.60906559]x + 21
# done
# left line
# y = [-0.73089463]x + 654
# right line
# y = [ 0.6034258]x + 23
# done
# left line
# y = [-0.71377897]x + 645
# right line
# y = [ 0.60133445]x + 22
# done
# left line
# y = [-0.69994217]x + 642
# right line
# y = [ 0.56865382]x + 40
# done
# left line
#  49%|████▉     | 333/682 [00:19<00:22, 15.48it/s]
#  49%|████▉     | 336/682 [00:19<00:21, 16.11it/s]
# y = [-0.70094436]x + 644
# right line
# y = [ 0.58985269]x + 30
# done
# left line
# y = [-0.67364758]x + 630
# right line
# y = [ 0.54100275]x + 57
# done
# left line
# y = [-0.70285416]x + 647
# right line
# y = [ 0.59891558]x + 26
# done
# left line
# y = [-0.68021047]x + 636
# right line
# y = [ 0.59917724]x + 25
# done
#  50%|████▉     | 339/682 [00:19<00:19, 17.85it/s]
# left line
# y = [-0.68649429]x + 638
# right line
# y = [ 0.57092696]x + 43
# done
# left line
# y = [-0.68470901]x + 638
# right line
# y = [ 0.59902388]x + 25
# done
# left line
# y = [-0.68711573]x + 638
# right line
# y = [ 0.60292667]x + 24
# done
# left line
# y = [-0.68897718]x + 640
# right line
# y = [ 0.58486801]x + 37
# done
#  50%|█████     | 341/682 [00:19<00:20, 16.42it/s]
#  50%|█████     | 343/682 [00:19<00:21, 16.04it/s]
# left line
# y = [-0.68991494]x + 641
# right line
# y = [ 0.6077534]x + 22
# done
# left line
# y = [-0.68546861]x + 638
# right line
# y = [ 0.61045647]x + 19
# done
# left line
# y = [-0.6905278]x + 641
# right line
# y = [ 0.58373207]x + 33
# done
# left line
# y = [-0.70059317]x + 646
# right line
# y = [ 0.51350462]x + 71
# done
#  51%|█████     | 345/682 [00:19<00:20, 16.16it/s]
#  51%|█████     | 348/682 [00:20<00:19, 16.93it/s]
# left line
# y = [-0.68635631]x + 639
# right line
# y = [ 0.58589834]x + 32
# done
# left line
# y = [-0.69140714]x + 642
# right line
# y = [ 0.54591924]x + 53
# done
# left line
# y = [-0.7000286]x + 648
# right line
# y = [ 0.54715455]x + 53
# done
# left line
# y = [-0.68641907]x + 640
# right line
# y = [ 0.58311963]x + 36
# done
# left line
# y = [-0.67723602]x + 636
# right line
# y = [ 0.60312229]x + 24
# done
#  51%|█████▏    | 350/682 [00:20<00:19, 17.04it/s]
#  52%|█████▏    | 353/682 [00:20<00:18, 18.08it/s]
# left line
# y = [-0.68174249]x + 638
# right line
# y = [ 0.59269375]x + 30
# done
# left line
# y = [-0.67508566]x + 635
# right line
# y = [ 0.59746659]x + 30
# done
# left line
# y = [-0.68183035]x + 638
# right line
# y = [ 0.60132456]x + 26
# done
# left line
# y = [-0.67965162]x + 636
# right line
# y = [ 0.61952794]x + 13
# done
#  52%|█████▏    | 355/682 [00:20<00:18, 18.13it/s]
# left line
# y = [-0.68602628]x + 640
# right line
# y = [ 0.61971152]x + 11
# done
# left line
# y = [-0.68922317]x + 642
# right line
# y = [ 0.58882779]x + 30
# done
# left line
# y = [-0.68771821]x + 640
# right line
# y = [ 0.55547434]x + 49
# done
# left line
# y = [-0.68892884]x + 642
# right line
# y = [ 0.53324074]x + 62
# done
# left line
# y = [-0.70216131]x + 648
# right line
# y = [ 0.60306454]x + 26
# done
#  52%|█████▏    | 358/682 [00:20<00:17, 18.42it/s]
#  53%|█████▎    | 361/682 [00:20<00:16, 19.40it/s]
# left line
# y = [-0.68716913]x + 639
# right line
# y = [ 0.56785965]x + 40
# done
# left line
# y = [-0.67793512]x + 634
# right line
# y = [ 0.59458667]x + 28
# done
# left line
# y = [-0.69804472]x + 643
# right line
# y = [ 0.58676881]x + 34
# done
# left line
# y = [-0.67199433]x + 631
# right line
# y = [ 0.58837306]x + 33
# done
# left line
# y = [-0.69437516]x + 642
# right line
# y = [ 0.61233032]x + 19
# done
#  53%|█████▎    | 364/682 [00:20<00:16, 19.20it/s]
#  54%|█████▍    | 367/682 [00:20<00:15, 19.95it/s]
# left line
# y = [-0.67832536]x + 635
# right line
# y = [ 0.60493487]x + 26
# done
# left line
# y = [-0.68013811]x + 637
# right line
# y = [ 0.59795779]x + 28
# done
# left line
# y = [-0.71422565]x + 648
# right line
# y = [ 0.60424459]x + 24
# done
# left line
# y = [-0.70205092]x + 645
# right line
# y = [ 0.5964641]x + 32
# done
#  54%|█████▍    | 370/682 [00:21<00:15, 19.72it/s]
# left line
# y = [-0.69503599]x + 643
# right line
# y = [ 0.55604517]x + 51
# done
# left line
# y = [-0.71617889]x + 651
# right line
# y = [ 0.55530262]x + 50
# done
# left line
# y = [-0.72334528]x + 652
# right line
# y = [ 0.62015909]x + 16
# done
# left line
# y = [-0.71025515]x + 645
# right line
# y = [ 0.55339611]x + 49
# done
# left line
# y = [-0.70482963]x + 643
# right line
# y = [ 0.58488041]x + 35
# done
#  55%|█████▍    | 372/682 [00:21<00:15, 19.78it/s]
#  55%|█████▍    | 374/682 [00:21<00:16, 18.66it/s]
# left line
# y = [-0.73528731]x + 657
# right line
# y = [ 0.54794478]x + 53
# done
# left line
# y = [-0.70084459]x + 643
# right line
# y = [ 0.59553641]x + 31
# done
# left line
# y = [-0.69828343]x + 639
# right line
# y = [ 0.58953446]x + 34
# done
# left line
# y = [-0.7138238]x + 646
# right line
# y = [ 0.60273486]x + 27
# done
#  55%|█████▌    | 377/682 [00:21<00:15, 19.52it/s]
#  56%|█████▌    | 379/682 [00:21<00:17, 17.69it/s]
# left line
# y = [-0.70992357]x + 643
# right line
# y = [ 0.60592705]x + 26
# done
# left line
# y = [-0.7154544]x + 645
# right line
# y = [ 0.59955311]x + 29
# done
# left line
# y = [-0.71625179]x + 646
# right line
# y = [ 0.60249126]x + 27
# done
# left line
# y = [-0.70071709]x + 639
# right line
# y = [ 0.59812546]x + 28
# done
#  56%|█████▌    | 381/682 [00:21<00:18, 16.02it/s]
# left line
# y = [-0.70686442]x + 645
# right line
# y = [ 0.5555023]x + 52
# done
# left line
# y = [-0.70671594]x + 645
# right line
# y = [ 0.60969788]x + 21
# done
# left line
# y = [-0.69801623]x + 640
# right line
# y = [ 0.58983785]x + 33
# done
# left line
# y = [-0.71120322]x + 644
# right line
# y = [ 0.60861397]x + 22
# done
#  56%|█████▋    | 384/682 [00:22<00:19, 15.36it/s]
#  57%|█████▋    | 386/682 [00:22<00:18, 15.86it/s]
#  57%|█████▋    | 388/682 [00:22<00:18, 16.09it/s]
# left line
# y = [-0.72332352]x + 652
# right line
# y = [ 0.60507238]x + 24
# done
# left line
# y = [-0.69391555]x + 638
# right line
# y = [ 0.58531648]x + 34
# done
# left line
# y = [-0.67155975]x + 631
# right line
# y = [ 0.60533088]x + 24
# done
# left line
# y = [-0.68139881]x + 632
# right line
# y = [ 0.61428034]x + 18
# done
#  57%|█████▋    | 390/682 [00:22<00:17, 16.32it/s]
#  57%|█████▋    | 392/682 [00:22<00:17, 17.04it/s]
# left line
# y = [-0.69956249]x + 640
# right line
# y = [ 0.59276646]x + 28
# done
# left line
# y = [-0.69954824]x + 640
# right line
# y = [ 0.59476209]x + 28
# done
# left line
# y = [-0.68069035]x + 634
# right line
# y = [ 0.62151259]x + 15
# done
# left line
# y = [-0.6996243]x + 642
# right line
# y = [ 0.60981679]x + 21
# done
#  58%|█████▊    | 394/682 [00:22<00:16, 17.08it/s]
# left line
# y = [-0.66903573]x + 628
# right line
# y = [ 0.51438373]x + 76
# done
# left line
# y = [-0.67598993]x + 630
# right line
# y = [ 0.55008775]x + 57
# done
# left line
# y = [-0.67488509]x + 628
# right line
# y = [ 0.62655866]x + 12
# done
# left line
# y = [-0.68051207]x + 633
# right line
# y = [ 0.64202613]x + 4
# done
# left line
# y = [-0.69134694]x + 637
# right line
# y = [ 0.64860004]x + -1
# done
#  58%|█████▊    | 397/682 [00:22<00:15, 18.23it/s]
#  59%|█████▊    | 399/682 [00:22<00:15, 18.56it/s]
#  59%|█████▉    | 402/682 [00:22<00:14, 19.74it/s]
# left line
# y = [-0.68668735]x + 635
# right line
# y = [ 0.58380979]x + 36
# done
# left line
# y = [-0.70083237]x + 642
# right line
# y = [ 0.648247]x + 0
# done
# left line
# y = [-0.69982183]x + 643
# right line
# y = [ 0.63308316]x + 9
# done
# left line
# y = [-0.65685737]x + 625
# right line
# y = [ 0.64988184]x + 0
# done
# left line
# y = [-0.66333145]x + 627
# right line
# y = [ 0.62899661]x + 12
# done
#  59%|█████▉    | 405/682 [00:23<00:15, 18.35it/s]
# left line
# y = [-0.67330813]x + 629
# right line
# y = [ 0.63775277]x + 6
# done
# left line
# y = [-0.68262249]x + 634
# right line
# y = [ 0.64550871]x + 3
# done
# left line
# y = [-0.68584108]x + 636
# right line
# y = [ 0.62312442]x + 14
# done
# left line
# y = [-0.6574046]x + 625
# right line
# y = [ 0.60964471]x + 21
# done
#  60%|█████▉    | 408/682 [00:23<00:14, 18.72it/s]
# left line
# y = [-0.68858665]x + 638
# right line
# y = [ 0.61647928]x + 17
# done
# left line
# y = [-0.67963642]x + 634
# right line
# y = [ 0.63823062]x + 5
# done
# left line
# y = [-0.69988275]x + 645
# right line
# y = [ 0.63116843]x + 9
# done
# left line
# y = [-0.69042712]x + 638
# right line
# y = [ 0.64194393]x + 3
# done
#  60%|██████    | 411/682 [00:23<00:13, 19.45it/s]
#  61%|██████    | 413/682 [00:23<00:14, 18.29it/s]
# left line
# y = [-0.67616773]x + 632
# right line
# y = [ 0.62491703]x + 12
# done
# left line
# y = [-0.69256675]x + 638
# right line
# y = [ 0.63508499]x + 6
# done
# left line
# y = [-0.69893032]x + 644
# right line
# y = [ 0.64298135]x + 0
# done
# left line
# y = [-0.6956085]x + 640
# right line
# y = [ 0.63931292]x + 0
# done
#  61%|██████    | 415/682 [00:23<00:14, 18.28it/s]
#  61%|██████    | 417/682 [00:23<00:14, 18.15it/s]
# left line
# y = [-0.69428098]x + 641
# right line
# y = [ 0.6426844]x + 0
# done
# left line
# y = [-0.70585948]x + 645
# right line
# y = [ 0.62494129]x + 9
# done
# left line
# y = [-0.69108838]x + 639
# right line
# y = [ 0.61369717]x + 16
# done
# left line
# y = [-0.69261807]x + 640
# right line
# y = [ 0.62205309]x + 12
# done
# left line
# y = [-0.69490373]x + 642
# right line
# y = [ 0.5951376]x + 29
# done
#  62%|██████▏   | 420/682 [00:23<00:14, 18.12it/s]
#  62%|██████▏   | 422/682 [00:24<00:14, 17.84it/s]
# left line
# y = [-0.69902402]x + 642
# right line
# y = [ 0.64061242]x + 2
# done
# left line
# y = [-0.69922119]x + 647
# right line
# y = [ 0.64054126]x + 3
# done
# left line
# y = [-0.69415647]x + 642
# right line
# y = [ 0.62086231]x + 13
# done
#  62%|██████▏   | 424/682 [00:24<00:14, 17.80it/s]
# left line
# y = [-0.69558382]x + 642
# right line
# y = [ 0.64288521]x + 0
# done
# left line
# y = [-0.69076359]x + 639
# right line
# y = [ 0.64522767]x + 0
# done
# left line
# y = [-0.69117689]x + 639
# right line
# y = [ 0.62606877]x + 9
# done
# left line
# y = [-0.68392873]x + 636
# right line
# y = [ 0.63290507]x + 6
# done
# left line
# y = [-0.6957615]x + 643
# right line
# y = [ 0.62875104]x + 8
# done
#  63%|██████▎   | 427/682 [00:24<00:14, 17.26it/s]
#  63%|██████▎   | 430/682 [00:24<00:13, 18.36it/s]
# left line
# y = [-0.6763767]x + 635
# right line
# y = [ 0.62646163]x + 10
# done
# left line
# y = [-0.68733084]x + 639
# right line
# y = [ 0.55768371]x + 44
# done
# left line
# y = [-0.68582326]x + 638
# right line
# y = [ 0.62032878]x + 12
# done
# left line
# y = [-0.67211461]x + 632
# right line
# y = [ 0.61950552]x + 12
# done
# left line
# y = [-0.68745631]x + 638
# right line
# y = [ 0.64245307]x + 0
# done
#  63%|██████▎   | 433/682 [00:24<00:13, 18.57it/s]
#  64%|██████▍   | 435/682 [00:24<00:13, 18.92it/s]
# left line
# y = [-0.69234425]x + 640
# right line
# y = [ 0.62963253]x + 7
# done
# left line
# y = [-0.69091147]x + 640
# right line
# y = [ 0.63802642]x + 3
# done
# left line
# y = [-0.68695587]x + 636
# right line
# y = [ 0.64152604]x + 1
# done
# left line
# y = [-0.69185674]x + 640
# right line
# y = [ 0.63189876]x + 7
# done
# left line
# y = [-0.68860507]x + 637
# right line
# y = [ 0.62282217]x + 11
# done
#  64%|██████▍   | 437/682 [00:24<00:12, 18.93it/s]
#  65%|██████▍   | 440/682 [00:25<00:12, 19.77it/s]
#  65%|██████▍   | 442/682 [00:25<00:12, 19.76it/s]
# left line
# y = [-0.69152856]x + 639
# right line
# y = [ 0.6324966]x + 6
# done
# left line
# y = [-0.68657911]x + 636
# right line
# y = [ 0.6341489]x + 5
# done
# left line
# y = [-0.68695039]x + 635
# right line
# y = [ 0.63098335]x + 6
# done
# left line
# y = [-0.69803613]x + 639
# right line
# y = [ 0.64134437]x + 1
# done
# left line
# y = [-0.696262]x + 639
# right line
# y = [-0.28716204]x + 441
# done
#  65%|██████▌   | 445/682 [00:25<00:12, 19.48it/s]
# left line
# y = [-0.70063931]x + 643
# right line
# y = [ 0.62936676]x + 7
# done
# left line
# y = [-0.70312297]x + 642
# right line
# y = [ 0.53439718]x + 59
# done
# left line
# y = [-0.69414431]x + 639
# right line
# y = [ 0.60105151]x + 22
# done
# left line
# y = [-0.69876939]x + 641
# right line
# y = [ 0.62429434]x + 11
# done
# left line
# y = [-0.68772316]x + 635
#  66%|██████▌   | 448/682 [00:25<00:12, 18.91it/s]
#  66%|██████▌   | 451/682 [00:25<00:11, 20.84it/s]
# right line
# y = [ 0.62781388]x + 10
# done
# left line
# y = [-0.69327646]x + 637
# right line
# y = [ 0.63506109]x + 5
# done
# left line
# y = [-0.68465692]x + 632
# right line
# y = [ 0.6298815]x + 6
# done
# left line
# y = [-0.68404841]x + 631
# right line
# y = [ 0.63465959]x + 3
# done
# left line
# y = [-0.68569613]x + 633
# right line
# y = [ 0.63425559]x + 4
# done
#  67%|██████▋   | 454/682 [00:25<00:11, 19.16it/s]
# left line
# y = [-0.68663067]x + 633
# right line
# y = [ 0.62814146]x + 8
# done
# left line
# y = [-0.68921602]x + 634
# right line
# y = [ 0.62978554]x + 5
# done
# left line
# y = [-0.69597924]x + 636
# right line
# y = [ 0.62160975]x + 9
# done
# left line
# y = [-0.69119936]x + 634
# right line
# y = [ 0.62354445]x + 7
# done
#  67%|██████▋   | 457/682 [00:25<00:11, 20.06it/s]
#  67%|██████▋   | 460/682 [00:26<00:10, 21.02it/s]
# left line
# y = [-0.70258683]x + 638
# right line
# y = [ 0.63625783]x + 1
# done
# left line
# y = [-0.66558236]x + 626
# right line
# y = [ 0.65202582]x + -6
# done
# left line
# y = [-0.64591151]x + 620
# right line
# y = [ 0.64424795]x + 0
# done
# left line
# y = [-0.65123981]x + 621
# right line
# y = [ 0.58001035]x + 35
# done
# left line
# y = [-0.66029429]x + 626
# right line
# y = [ 0.62706816]x + 7
# done
#  68%|██████▊   | 463/682 [00:26<00:10, 20.50it/s]
# left line
# y = [-0.69534689]x + 640
# right line
# y = [ 0.61566252]x + 14
# done
# left line
# y = [-0.69631749]x + 639
# right line
# y = [ 0.6275183]x + 7
# done
# left line
# y = [-0.678774]x + 632
# right line
# y = [ 0.63326216]x + 4
# done
# left line
# y = [-0.6833359]x + 636
# right line
# y = [ 0.62399673]x + 11
# done
#  68%|██████▊   | 466/682 [00:26<00:10, 19.86it/s]
# left line
# y = [-0.6757881]x + 634
# right line
# y = [ 0.62833506]x + 8
# done
# left line
# y = [-0.69068027]x + 639
# right line
# y = [ 0.502388]x + 74
# done
# left line
# y = [-0.67336023]x + 633
# right line
# y = [ 0.60207969]x + 22
# done
# left line
# y = [-0.65724099]x + 625
# right line
# y = [ 0.60985386]x + 17
# done
# left line
# y = [-0.67621285]x + 632
# right line
# y = [ 0.54947114]x + 50
# done
#  69%|██████▉   | 469/682 [00:26<00:11, 19.35it/s]
#  69%|██████▉   | 472/682 [00:26<00:10, 20.36it/s]
# left line
# y = [-0.66108471]x + 627
# right line
# y = [ 0.60723692]x + 20
# done
# left line
# y = [-0.67337316]x + 634
# right line
# y = [ 0.60805249]x + 21
# done
# left line
# y = [-0.73881418]x + 662
# right line
# y = [ 0.60777277]x + 21
# done
# left line
# y = [-0.67316419]x + 634
# right line
# y = [ 0.60812366]x + 21
# done
# left line
# y = [-0.67386526]x + 635
# right line
# y = [ 0.61249942]x + 19
# done
#  70%|██████▉   | 475/682 [00:26<00:10, 20.36it/s]
#  70%|███████   | 478/682 [00:26<00:10, 20.28it/s]
# left line
# y = [-0.68813545]x + 639
# right line
# y = [ 0.62334704]x + 13
# done
# left line
# y = [-0.68523943]x + 639
# right line
# y = [ 0.63534284]x + 5
# done
# left line
# y = [-0.69418627]x + 643
# right line
# y = [ 0.62215501]x + 14
# done
# left line
# y = [-0.69079912]x + 642
# right line
# y = [ 0.61135155]x + 19
# done
# left line
# y = [-0.69029325]x + 641
# right line
# y = [ 0.61006677]x + 20
# done
#  71%|███████   | 481/682 [00:27<00:10, 20.10it/s]
# left line
# y = [-0.68914717]x + 642
# right line
# y = [ 0.59871387]x + 26
# done
# left line
# y = [-0.68895835]x + 641
# right line
# y = [ 0.63795298]x + 4
# done
# left line
# y = [-0.69958955]x + 646
# right line
# y = [ 0.62856245]x + 9
# done
# left line
# y = [-0.69224072]x + 644
# right line
# y = [ 0.63883877]x + 3
# done
#  71%|███████   | 484/682 [00:27<00:10, 19.75it/s]
#  71%|███████▏  | 487/682 [00:27<00:10, 19.29it/s]
# left line
# y = [-0.68819267]x + 643
# right line
# y = [ 0.65556741]x + -5
# done
# left line
# y = [-0.68653709]x + 641
# right line
# y = [ 0.62963253]x + 7
# done
# left line
# y = [-0.6845082]x + 636
# right line
# y = [ 0.63045079]x + 5
# done
# left line
# y = [-0.68920928]x + 639
# right line
# y = [ 0.63510519]x + 3
# done
# left line
# y = [-0.68678331]x + 636
# right line
# y = [ 0.62580967]x + 6
# done
#  72%|███████▏  | 489/682 [00:27<00:09, 19.46it/s]
#  72%|███████▏  | 492/682 [00:27<00:09, 19.29it/s]
# left line
# y = [-0.68636745]x + 638
# right line
# y = [ 0.64624012]x + -3
# done
# left line
# y = [-0.69162452]x + 642
# right line
# y = [ 0.63842964]x + 1
# done
# left line
# y = [-0.68428153]x + 636
# right line
# y = [ 0.63949955]x + 1
# done
# left line
# y = [-0.67468715]x + 630
# right line
# y = [ 0.61790246]x + 14
# done
# left line
# y = [-0.68734062]x + 637
# right line
# y = [ 0.61775512]x + 13
# done
#  73%|███████▎  | 495/682 [00:27<00:09, 20.26it/s]
# left line
# y = [-0.68715453]x + 639
# right line
# y = [ 0.55365205]x + 49
# done
# left line
# y = [-0.67708826]x + 633
# right line
# y = [ 0.62424999]x + 9
# done
# left line
# y = [-0.67401445]x + 630
# right line
# y = [ 0.63882935]x + 1
# done
# left line
# y = [-0.67323083]x + 630
# right line
# y = [ 0.59890264]x + 25
# done
# left line
# y = [-0.69984996]x + 644
# right line
# y = [ 0.62730837]x + 6
# done
#  73%|███████▎  | 498/682 [00:27<00:09, 19.36it/s]
#  73%|███████▎  | 501/682 [00:28<00:08, 20.57it/s]
# left line
# y = [-0.69548374]x + 641
# right line
# y = [ 0.62105227]x + 10
# done
# left line
# y = [-0.69355696]x + 640
# right line
# y = [ 0.60659575]x + 18
# done
# left line
# y = [-0.6906808]x + 640
# right line
# y = [ 0.63453513]x + 2
# done
# left line
# y = [-0.67888027]x + 634
# right line
# y = [ 0.60918617]x + 16
# done
# left line
# y = [-0.67898434]x + 635
# right line
# y = [ 0.61080509]x + 16
# done
#  74%|███████▍  | 504/682 [00:28<00:08, 20.56it/s]
#  74%|███████▍  | 507/682 [00:28<00:08, 20.01it/s]
# left line
# y = [-0.6762327]x + 633
# right line
# y = [ 0.47633064]x + 87
# done
# left line
# y = [-0.68712044]x + 639
# right line
# y = [ 0.62201238]x + 10
# done
# left line
# y = [-0.68518698]x + 638
# right line
# ...
# y = [-0.69951415]x + 643
# right line
# y = [ 0.62806696]x + 10
# done
#  76%|███████▌  | 518/682 [00:28<00:08, 19.84it/s]
# left line
# y = [-0.69299102]x + 640
# right line
# y = [ 0.62898749]x + 9
# done
# left line
# y = [-0.67611486]x + 632
# right line
# y = [ 0.63985693]x + 2
# done
# left line
# y = [-0.6895386]x + 637
# right line
# y = [ 0.63515681]x + 4
# done
# left line
# y = [-0.69969016]x + 642
# right line
# y = [ 0.59067267]x + 28
# done
# left line
# y = [-0.68485844]x + 636
# right line
# y = [ 0.62980402]x + 8
# done
#  76%|███████▋  | 521/682 [00:29<00:07, 21.16it/s]
#  77%|███████▋  | 524/682 [00:29<00:07, 19.82it/s]
# left line
# y = [-0.69766766]x + 642
# right line
# y = [ 0.66511267]x + -12
# done
# left line
# y = [-0.65930408]x + 628
# right line
# y = [ 0.57596314]x + 39
# done
# left line
# y = [-0.6588068]x + 627
# right line
# y = [ 0.6483106]x + -5
# done
# left line
# y = [-0.66125047]x + 630
# right line
# y = [ 0.63080287]x + 4
# done
#  77%|███████▋  | 527/682 [00:29<00:07, 19.67it/s]
# left line
# y = [-0.667373]x + 632
# right line
# y = [ 0.62139088]x + 12
# done
# left line
# y = [-0.65460515]x + 627
# right line
# y = [ 0.6321789]x + 4
# done
# left line
# y = [-0.65011895]x + 624
# right line
# y = [ 0.63595408]x + 3
# done
# left line
# y = [-0.67733604]x + 636
# right line
# y = [ 0.63139629]x + 5
# done
#  78%|███████▊  | 530/682 [00:29<00:07, 19.36it/s]
#  78%|███████▊  | 532/682 [00:29<00:07, 19.21it/s]
# left line
# y = [-0.67486566]x + 636
# right line
# y = [ 0.63906038]x + 2
# done
# left line
# y = [-0.68885672]x + 641
# right line
# y = [ 0.63069201]x + 4
# done
# left line
# y = [-0.68256164]x + 640
# right line
# y = [ 0.63443208]x + 3
# done
# left line
# y = [-0.69668752]x + 645
# right line
# y = [ 0.62436014]x + 8
# done
#  78%|███████▊  | 535/682 [00:29<00:07, 19.37it/s]
# left line
# y = [-0.69813639]x + 645
# right line
# y = [ 0.64066577]x + 0
# done
# left line
# y = [-0.70614415]x + 650
# right line
# y = [ 0.66084659]x + -12
# done
# left line
# y = [-0.70743656]x + 651
# right line
# y = [ 0.62943345]x + 6
# done
# left line
# y = [-0.6919415]x + 643
# right line
# y = [ 0.63064384]x + 5
# done
# left line
# y = [-0.70071858]x + 647
#  79%|███████▉  | 538/682 [00:29<00:07, 19.83it/s]
#  79%|███████▉  | 540/682 [00:30<00:07, 18.94it/s]
# right line
# y = [ 0.65703028]x + -14
# done
# left line
# y = [-0.68410176]x + 640
# right line
# y = [ 0.6793524]x + -28
# done
# left line
# y = [-0.708525]x + 651
# right line
# y = [ 0.63666612]x + 2
# done
# left line
# y = [-0.68705821]x + 642
# right line
# y = [ 0.64069134]x + 0
# done
#  79%|███████▉  | 542/682 [00:30<00:07, 18.38it/s]
#  80%|███████▉  | 544/682 [00:30<00:07, 18.73it/s]
# left line
# y = [-0.6857208]x + 643
# right line
# y = [ 0.52354699]x + 61
# done
# left line
# y = [-0.67797887]x + 637
# right line
# y = [ 0.65532374]x + -9
# done
# left line
# y = [-0.68810493]x + 643
# right line
# y = [ 0.63722479]x + 0
# done
# left line
# y = [-0.68784422]x + 643
# right line
# y = [ 0.56473249]x + 39
# done
#  80%|████████  | 546/682 [00:30<00:07, 18.59it/s]
#  80%|████████  | 548/682 [00:30<00:07, 18.87it/s]
# left line
# y = [-0.67536837]x + 635
# right line
# y = [ 0.63791889]x + 0
# done
# left line
# y = [-0.6817112]x + 641
# right line
# y = [ 0.63929445]x + -1
# done
# left line
# y = [-0.6826846]x + 640
# right line
# y = [ 0.67960221]x + -31
# done
# left line
# y = [-0.68442643]x + 639
# right line
# y = [ 0.63554758]x + -1
# done
# left line
# y = [-0.70199496]x + 646
# right line
# y = [ 0.61649221]x + 8
# done
#  81%|████████  | 551/682 [00:30<00:06, 20.48it/s]
# left line
# y = [-0.70756614]x + 651
# right line
# y = [ 0.62516463]x + 5
# done
# left line
# y = [-0.69861138]x + 646
# right line
# y = [ 0.61713809]x + 9
# done
# left line
# y = [-0.72646427]x + 659
# right line
# y = [ 0.61695457]x + 9
# done
# left line
# y = [-0.72128981]x + 655
# right line
# y = [ 0.63425183]x + 0
# done
# left line
# y = [-0.71442086]x + 654
# right line
# y = [ 0.63528079]x + 0
# done
#  81%|████████  | 554/682 [00:30<00:06, 20.46it/s]
#  82%|████████▏ | 557/682 [00:30<00:06, 19.98it/s]
# left line
# y = [-0.72227794]x + 657
# right line
# y = [ 0.64295298]x + -4
# done
# left line
# y = [-0.72483933]x + 660
# right line
# y = [ 0.63123286]x + 1
# done
# left line
# y = [-0.72016555]x + 654
# right line
# y = [ 0.62823522]x + 3
# done
# left line
# y = [-0.71034819]x + 649
# right line
# y = [ 0.63945311]x + -3
# done
# left line
# y = [-0.72435337]x + 656
# right line
# y = [ 0.59375244]x + 23
# done
#  82%|████████▏ | 560/682 [00:31<00:06, 20.02it/s]
#  83%|████████▎ | 563/682 [00:31<00:06, 19.69it/s]
# left line
# y = [-0.70826262]x + 651
# right line
# y = [ 0.6098507]x + 12
# done
# left line
# y = [-0.7118727]x + 652
# right line
# y = [ 0.62566346]x + 3
# done
# left line
# y = [-0.72157258]x + 657
# right line
# y = [ 0.6184594]x + 6
# done
# left line
# y = [-0.72435588]x + 658
# right line
# y = [ 0.61674863]x + 8
# done
#  83%|████████▎ | 565/682 [00:31<00:06, 18.51it/s]
#  83%|████████▎ | 567/682 [00:31<00:06, 18.72it/s]
# left line
# y = [-0.70796597]x + 650
# right line
# y = [ 0.63292062]x + 0
# done
# left line
# y = [-0.71572447]x + 653
# right line
# y = [ 0.59885347]x + 17
# done
# left line
# y = [-0.71629328]x + 655
# right line
# y = [ 0.63121015]x + 0
# done
# left line
# y = [-0.69029772]x + 645
# right line
# y = [ 0.65233189]x + -11
# done
#  83%|████████▎ | 569/682 [00:31<00:06, 17.82it/s]
# left line
# y = [-0.71945977]x + 656
# right line
# y = [ 0.63631278]x + -2
# done
# left line
# y = [-0.7280671]x + 660
# right line
# y = [ 0.6124438]x + 10
# done
# left line
# y = [-0.74383235]x + 664
# right line
# y = [ 0.61601543]x + 9
# done
# left line
# y = [-0.75019622]x + 670
# right line
# y = [ 0.6148774]x + 8
# done
#  84%|████████▍ | 572/682 [00:31<00:06, 18.18it/s]
#  84%|████████▍ | 575/682 [00:31<00:05, 19.84it/s]
# left line
# y = [-0.75981498]x + 673
# right line
# y = [ 0.59576148]x + 19
# done
# left line
# y = [-0.74256432]x + 666
# right line
# y = [ 0.5894419]x + 23
# done
# left line
# y = [-0.74039674]x + 665
# right line
# y = [ 0.60223705]x + 15
# done
# left line
# y = [-0.72735047]x + 661
# right line
# y = [ 0.60996383]x + 12
# done
# left line
# y = [-0.73363304]x + 663
# right line
# y = [ 0.58493102]x + 24
# done
#  85%|████████▍ | 578/682 [00:32<00:05, 18.40it/s]
#  85%|████████▌ | 580/682 [00:32<00:05, 17.72it/s]
# left line
# y = [-0.76086605]x + 674
# right line
# y = [ 0.59926778]x + 18
# done
# left line
# y = [-0.75088739]x + 670
# right line
# y = [ 0.61110002]x + 11
# done
# left line
# y = [-0.75483441]x + 671
# right line
# y = [ 0.60562402]x + 11
# done
# left line
# y = [-0.81214035]x + 690
# right line
# y = [ 0.58289641]x + 24
# done
#  85%|████████▌ | 583/682 [00:32<00:05, 18.53it/s]
# left line
# y = [-0.78056908]x + 683
# right line
# y = [ 0.59507024]x + 18
# done
# left line
# y = [-0.7803213]x + 684
# right line
# y = [ 0.59015816]x + 21
# done
# left line
# y = [-0.7640996]x + 673
# right line
# y = [ 0.57889253]x + 28
# done
# left line
# y = [-0.76833349]x + 676
# right line
# y = [ 0.5763272]x + 30
# done
# left line
# y = [-0.75540805]x + 671
# right line
# y = [ 0.58007222]x + 29
# done
#  86%|████████▌ | 586/682 [00:32<00:05, 18.82it/s]
#  86%|████████▋ | 589/682 [00:32<00:04, 19.78it/s]
# left line
# y = [-0.77674681]x + 681
# right line
# y = [ 0.59430122]x + 20
# done
# left line
# y = [-0.76311857]x + 676
# right line
# y = [ 0.59683245]x + 19
# done
# left line
# y = [-0.70772123]x + 651
# right line
# y = [ 0.56491035]x + 37
# done
# left line
# y = [-0.78044498]x + 685
# right line
# y = [ 0.65615338]x + -20
# done
# left line
# y = [-0.75404561]x + 676
# right line
# y = [ 0.49858224]x + 74
# done
#  87%|████████▋ | 592/682 [00:32<00:04, 19.41it/s]
# left line
# y = [-0.74854159]x + 669
# right line
# y = [ 0.58696449]x + 26
# done
# left line
# y = [-0.74520576]x + 671
# right line
# y = [ 0.58595532]x + 28
# done
# left line
# y = [-0.72155792]x + 662
# right line
# y = [ 0.5671041]x + 37
# done
# left line
# y = [-0.73960972]x + 670
# right line
# y = [ 0.6000011]x + 21
# done
#  87%|████████▋ | 595/682 [00:32<00:04, 19.77it/s]
#  88%|████████▊ | 598/682 [00:33<00:04, 20.54it/s]
# left line
# y = [-0.74519223]x + 673
# right line
# y = [ 0.54313785]x + 55
# done
# left line
# y = [-0.74863493]x + 676
# right line
# y = [ 0.59113944]x + 27
# done
# left line
# y = [-0.75289756]x + 674
# right line
# y = [ 0.58008766]x + 33
# done
# left line
# y = [-0.75098503]x + 675
# right line
# y = [ 0.56611174]x + 39
# done
# left line
# y = [-0.80064052]x + 684
# right line
# y = [ 0.58953494]x + 27
# done
#  88%|████████▊ | 601/682 [00:33<00:04, 19.96it/s]
# left line
# y = [-0.78261983]x + 688
# right line
# y = [ 0.59437871]x + 24
# done
# left line
# y = [-0.76844108]x + 681
# right line
# y = [ 0.57523775]x + 33
# done
# left line
# y = [-0.74176794]x + 671
# right line
# y = [ 0.57467812]x + 33
# done
# left line
#  89%|████████▊ | 604/682 [00:33<00:03, 20.34it/s]
#  89%|████████▉ | 607/682 [00:33<00:03, 21.09it/s]
# y = [-0.76582414]x + 680
# right line
# y = [ 0.58916318]x + 22
# done
# left line
# y = [-0.74425972]x + 669
# right line
# y = [ 0.56771016]x + 34
# done
# left line
# y = [-0.73117346]x + 669
# right line
# y = [ 0.56889182]x + 34
# done
# left line
# y = [-0.75803679]x + 677
# right line
# y = [ 0.57483673]x + 31
# done
# left line
# y = [-0.76045209]x + 678
# right line
# y = [ 0.55628949]x + 43
# done
# left line
# y = [-0.74153876]x + 672
# right line
# y = [ 0.57551277]x + 32
# done
#  89%|████████▉ | 610/682 [00:33<00:03, 19.05it/s]
#  90%|████████▉ | 612/682 [00:33<00:03, 17.91it/s]
# left line
# y = [-0.76357621]x + 677
# right line
# y = [ 0.55720955]x + 43
# done
# left line
# y = [-0.80000228]x + 694
# right line
# y = [ 0.58331323]x + 27
# done
# left line
# y = [-0.76086348]x + 679
# right line
# y = [ 0.58510071]x + 27
# done
# left line
# y = [-0.78062552]x + 688
# right line
# y = [ 0.57790804]x + 31
# done
#  90%|█████████ | 614/682 [00:33<00:03, 17.92it/s]
# left line
# y = [-0.77845991]x + 686
# right line
# y = [ 0.58505094]x + 27
# done
# left line
# y = [-0.77137005]x + 683
# right line
# y = [ 0.49113947]x + 76
# done
# left line
# y = [-0.77804708]x + 687
# right line
# y = [ 0.56853855]x + 36
# done
# left line
# y = [-0.80988294]x + 700
# right line
# y = [ 0.57445693]x + 33
# done
# left line
# y = [-0.78354448]x + 688
# right line
# y = [ 0.57182813]x + 35
#  90%|█████████ | 617/682 [00:34<00:03, 18.47it/s]
#  91%|█████████ | 620/682 [00:34<00:03, 18.52it/s]
# done
# left line
# y = [-0.77594376]x + 685
# right line
# y = [ 0.57501775]x + 33
# done
# left line
# y = [-0.79729205]x + 697
# right line
# y = [ 0.56462228]x + 39
# done
# left line
# y = [-0.80529845]x + 698
# right line
# y = [ 0.57299769]x + 33
# done
#  91%|█████████ | 622/682 [00:34<00:03, 17.96it/s]
# left line
# y = [-0.80951369]x + 698
# right line
# y = [ 0.57198161]x + 34
# done
# left line
# y = [-0.79758966]x + 693
# right line
# y = [ 0.58216584]x + 26
# done
# left line
# y = [-0.80136013]x + 692
# right line
# y = [ 0.55684978]x + 42
# done
# left line
# y = [-0.81956327]x + 700
# right line
# y = [ 0.57228684]x + 31
# done
#  91%|█████████▏| 624/682 [00:34<00:03, 16.64it/s]
#  92%|█████████▏| 626/682 [00:34<00:03, 16.62it/s]
# left line
# y = [-0.81576377]x + 697
# right line
# y = [ 0.56857175]x + 34
# done
# left line
# y = [-0.83577782]x + 706
# right line
# y = [ 0.55963266]x + 37
# done
# left line
# y = [-0.80145323]x + 693
# right line
# y = [ 0.57306099]x + 31
# done
# left line
# y = [-0.81610811]x + 700
# right line
# y = [ 0.58127344]x + 28
# done
#  92%|█████████▏| 629/682 [00:34<00:03, 17.02it/s]
# left line
# y = [-0.82948279]x + 704
# right line
# y = [ 0.55838907]x + 39
# done
# left line
# y = [-0.80538142]x + 695
# right line
# y = [ 0.50229412]x + 71
# done
# left line
# y = [-0.81784928]x + 702
# right line
# y = [ 0.52861083]x + 57
# done
# left line
# y = [-0.83420908]x + 707
# right line
# y = [ 0.54539073]x + 50
# done
#  93%|█████████▎| 632/682 [00:34<00:03, 15.63it/s]
#  93%|█████████▎| 634/682 [00:35<00:03, 14.02it/s]
# left line
# y = [-0.81885487]x + 702
# right line
# y = [ 0.56730485]x + 37
# done
# left line
# y = [-0.81891787]x + 701
# right line
# y = [ 0.595864]x + 21
# done
# left line
# y = [-0.78163064]x + 681
# right line
# y = [ 0.5740571]x + 33
# done
# left line
# y = [-0.80347073]x + 692
# right line
# y = [ 0.57919985]x + 30
# done
#  93%|█████████▎| 636/682 [00:35<00:03, 13.90it/s]
#  94%|█████████▎| 639/682 [00:35<00:02, 15.38it/s]
# left line
# y = [-0.78154409]x + 680
# right line
# y = [ 0.58622116]x + 26
# done
# left line
# y = [-0.79734379]x + 689
# right line
# y = [ 0.57631218]x + 33
# done
# left line
# y = [-0.79742575]x + 691
# right line
# y = [ 0.59498036]x + 22
# done
# left line
# y = [-0.7986002]x + 689
# right line
# y = [ 0.55176789]x + 47
# done
# left line
#  94%|█████████▍| 641/682 [00:35<00:02, 15.96it/s]
#  94%|█████████▍| 644/682 [00:35<00:02, 16.86it/s]
# y = [-0.80793566]x + 694
# right line
# y = [ 0.58060324]x + 31
# done
# left line
# y = [-0.7922371]x + 687
# right line
# y = [ 0.54941005]x + 48
# done
# left line
# y = [-0.7931872]x + 686
# right line
# y = [ 0.57947248]x + 31
# done
# left line
# y = [-0.75437182]x + 667
# right line
# y = [ 0.56601048]x + 38
# done
#  95%|█████████▍| 646/682 [00:35<00:02, 16.90it/s]
#  95%|█████████▌| 648/682 [00:35<00:02, 16.73it/s]
# left line
# y = [-0.8084926]x + 694
# right line
# y = [ 0.59224117]x + 22
# done
# left line
# y = [-0.77835423]x + 681
# right line
# y = [ 0.58548236]x + 29
# done
# left line
# y = [-0.74017137]x + 664
# right line
# y = [ 0.59075803]x + 26
# done
# left line
# y = [-0.80517149]x + 692
# right line
# y = [ 0.58879238]x + 27
# done
#  95%|█████████▌| 650/682 [00:36<00:01, 16.48it/s]
# left line
# y = [-0.77705812]x + 680
# right line
# y = [ 0.59706932]x + 23
# done
# left line
# y = [-0.79660559]x + 687
# right line
# y = [ 0.60638106]x + 17
# done
# left line
# y = [-0.78015983]x + 681
# right line
# y = [ 0.59833038]x + 20
# done
#  96%|█████████▌| 652/682 [00:36<00:01, 15.84it/s]
#  96%|█████████▌| 654/682 [00:36<00:01, 15.78it/s]
# left line
# y = [-0.75924098]x + 671
# right line
# y = [ 0.60013288]x + 20
# done
# left line
# y = [-0.75416952]x + 667
# right line
# y = [ 0.60113114]x + 19
# done
# left line
# y = [-0.7710852]x + 672
# right line
# y = [ 0.54446191]x + 53
# done
# left line
# y = [-0.77354461]x + 674
# right line
# y = [ 0.59915352]x + 19
# done
#  96%|█████████▌| 656/682 [00:36<00:01, 15.50it/s]
#  96%|█████████▋| 658/682 [00:36<00:01, 15.94it/s]
# left line
# y = [-0.75939113]x + 669
# right line
# y = [ 0.60257745]x + 18
# done
# left line
# y = [-0.7577014]x + 668
# right line
# y = [ 0.55406612]x + 49
# done
# left line
# y = [-0.74717957]x + 665
# right line
# y = [ 0.5782125]x + 35
# done
#  97%|█████████▋| 660/682 [00:36<00:01, 15.66it/s]
# left line
# y = [-0.72632647]x + 654
# right line
# y = [ 0.58173674]x + 33
# done
# left line
# y = [-0.72575396]x + 653
# right line
# y = [ 0.61302423]x + 12
# done
# left line
# y = [-0.73564988]x + 661
# right line
# y = [ 0.62725532]x + 0
# done
#  97%|█████████▋| 662/682 [00:36<00:01, 13.83it/s]
#  97%|█████████▋| 664/682 [00:37<00:01, 13.60it/s]
# left line
# y = [-0.73851901]x + 662
# right line
# y = [ 0.60934687]x + 16
# done
# left line
# y = [-0.73844284]x + 662
# right line
# y = [ 0.62433857]x + 7
# done
# left line
# y = [-0.7471168]x + 665
# right line
# y = [ 0.60650301]x + 15
# done
#  98%|█████████▊| 666/682 [00:37<00:01, 14.04it/s]
# left line
# y = [-0.74388045]x + 663
# right line
# y = [ 0.59404343]x + 21
# done
# left line
# y = [-0.72357571]x + 655
# right line
# y = [ 0.63780987]x + -2
# done
# left line
# y = [-0.69914263]x + 644
# right line
# y = [ 0.5938499]x + 23
# done
# left line
# y = [-0.69943446]x + 643
# right line
# y = [ 0.62315512]x + 4
# done
#  98%|█████████▊| 668/682 [00:37<00:00, 14.51it/s]
#  98%|█████████▊| 670/682 [00:37<00:00, 15.12it/s]
#  99%|█████████▊| 672/682 [00:37<00:00, 16.16it/s]
# left line
# y = [-0.70083714]x + 643
# right line
# y = [ 0.61143494]x + 11
# done
# left line
# y = [-0.71533781]x + 654
# right line
# y = [ 0.64053422]x + -2
# done
# left line
# y = [-0.71218807]x + 655
# right line
# y = [ 0.61758244]x + 10
# done
# left line
# y = [-0.7108047]x + 652
# right line
# y = [ 0.59867018]x + 20
# done
#  99%|█████████▉| 674/682 [00:37<00:00, 16.22it/s]
# left line
# y = [-0.7025851]x + 648
# right line
# y = [ 0.60292959]x + 18
# done
# left line
# y = [-0.7037273]x + 645
# right line
# y = [ 0.61057484]x + 14
# done
# left line
# y = [-0.70034224]x + 645
# right line
# y = [ 0.58448398]x + 28
# done
# left line
# y = [-0.77987629]x + 679
# right line
# y = [ 0.58062536]x + 32
# done
#  99%|█████████▉| 676/682 [00:37<00:00, 14.91it/s]
#  99%|█████████▉| 678/682 [00:37<00:00, 15.55it/s]
# left line
# y = [-0.69949996]x + 650
# right line
# y = [ 0.59535116]x + 24
# done
# left line
# y = [-0.73948008]x + 665
# right line
# y = [ 0.59317744]x + 25
# done
# left line
# y = [-0.75241733]x + 672
# right line
# y = [ 0.611453]x + 14
# done
# left line
# y = [-0.74341226]x + 664
# right line
# y = [ 0.60125291]x + 20
# done
# 100%|█████████▉| 680/682 [00:38<00:00, 15.32it/s]
# 100%|█████████▉| 681/682 [00:38<00:00, 17.84it/s]
# left line
# y = [-0.80588239]x + 690
# right line
# y = [ 0.59690344]x + 23
# done
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: test_videos_output/solidYellowLeft.mp4
#
# CPU times: user 15.4 s, sys: 2.2 s, total: 17.6 s
# Wall time: 39.6 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidYellowLeft.mp4">
# </video>

# %% [markdown]
# ## Writeup and Submission
#
# If you're satisfied with your video outputs, it's time to make the report writeup in a pdf or markdown file. Once you have this Ipython notebook ready along with the writeup, it's time to submit for review! Here is a [link](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) to the writeup template file.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
b = {'a': 1}

# %%
pipe = reload(pipe)
state_id = 'c'
def process_image(image):
    result = pipe.detect_lane(image, state_id)
    print('done')
    return result

challenge_output = 'test_videos_output/challenge.mp4'
clip3 = VideoFileClip('test_videos/challenge.mp4').subclip(3.75,4)
challenge_clip = clip3.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)
# Out:
# SLOPE:: -0.781553397606
# SLOPE:: -0.838541666146
# SLOPE:: 0.559999998665
# SLOPE:: 0.555555555147
# SLOPE:: 0.576086956149
# SLOPE:: -0.621212120932
# SLOPE:: -0.549999999344
# SLOPE:: -0.572815533318
# SLOPE:: -0.598360655153
# SLOPE:: -0.504504503963
# SLOPE:: -0.461538461213
# SLOPE:: -0.443349753434
# SLOPE:: -0.550847457071
# SLOPE:: -0.439393938997
# SLOPE:: 0.524590162909
# SLOPE:: -0.865591397295
# SLOPE:: -0.485074626434
# SLOPE:: -0.359550561316
# SLOPE:: 0.552083332991
# SLOPE:: -0.442396313121
# SLOPE:: -0.484848484265
# SLOPE:: -0.379310344308
# SLOPE:: -0.461538461213
# SLOPE:: -0.547619047101
# SLOPE:: -0.464285714039
# SLOPE:: -0.842592591663
# SLOPE:: -0.444444443909
# SLOPE:: -0.808510637785
# SLOPE:: -0.575757575238
# SLOPE:: -0.443786981935
# SLOPE:: -0.419642856696
# SLOPE:: -0.534482758071
# SLOPE:: -0.539999999356
# SLOPE:: -0.83774834404
# SLOPE:: -0.378378377769
# SLOPE:: -0.727272726397
# SLOPE:: -0.389473683722
# SLOPE:: -0.656249999185
# SLOPE:: -0.420833333124
# SLOPE:: 0.468468467965
# SLOPE:: -0.699029125405
# SLOPE:: -0.342105262621
# LEFT # 36 [-0.78155339760597853, -0.83854166614603143, -0.62121212093161271, -0.54999999934434896, -0.57281553331762203, -0.59836065515303161, -0.50450450396268809, -0.46153846121290137, -0.4433497534342295, -0.55084745707062599, -0.43939393899712242, -0.86559139729469603, -0.48507462643413879, -0.35955056131615992, -0.44239631312102418, -0.48484848426466221, -0.37931034430784694, -0.46153846121290137, -0.54761904710094222, -0.46428571403862873, -0.84259259166254752, -0.44444444390927368, -0.80851063778520227, -0.57575757523760873, -0.44378698193548205, -0.41964285669620244, -0.53448275807141976, -0.53999999935626986, -0.83774834404017418, -0.37837837776883487, -0.72727272639699325, -0.38947368372180124, -0.65624999918509275, -0.42083333312430315, -0.69902912540455564, -0.34210526262128782] [-0.62121212093161271, -0.54999999934434896, -0.57281553331762203, -0.59836065515303161, -0.50450450396268809, -0.46153846121290137, -0.4433497534342295, -0.55084745707062599, -0.43939393899712242, -0.48507462643413879, -0.44239631312102418, -0.48484848426466221, -0.37931034430784694, -0.46153846121290137, -0.54761904710094222, -0.46428571403862873, -0.44444444390927368, -0.57575757523760873, -0.44378698193548205, -0.41964285669620244, -0.53448275807141976, -0.53999999935626986, -0.37837837776883487, -0.38947368372180124, -0.65624999918509275, -0.42083333312430315]
# right # 6 [0.55999999866485595, 0.5555555551467446, 0.57608695614850591, 0.52459016290924554, 0.5520833329905549, 0.46846846796535324] [0.55999999866485595, 0.5555555551467446, 0.57608695614850591, 0.5520833329905549]
# y = [-0.52647567]x + 732
# y = [ 0.54800785]x + 64
# done
# [MoviePy] >>>> Building video test_videos_output/challenge.mp4
# [MoviePy] Writing video test_videos_output/challenge.mp4
#   0%|          | 0/7 [00:00<?, ?it/s]
# SLOPE:: -0.781553397606
# SLOPE:: -0.838541666146
# SLOPE:: 0.559999998665
# SLOPE:: 0.555555555147
# SLOPE:: 0.576086956149
# SLOPE:: -0.621212120932
# SLOPE:: -0.549999999344
# SLOPE:: -0.572815533318
# SLOPE:: -0.598360655153
# SLOPE:: -0.504504503963
# SLOPE:: -0.461538461213
# SLOPE:: -0.443349753434
# SLOPE:: -0.550847457071
# SLOPE:: -0.439393938997
# SLOPE:: 0.524590162909
# SLOPE:: -0.865591397295
# SLOPE:: -0.485074626434
# SLOPE:: -0.359550561316
# SLOPE:: 0.552083332991
# SLOPE:: -0.442396313121
# SLOPE:: -0.484848484265
# SLOPE:: -0.379310344308
# SLOPE:: -0.461538461213
# SLOPE:: -0.547619047101
# SLOPE:: -0.464285714039
# SLOPE:: -0.842592591663
# SLOPE:: -0.444444443909
# SLOPE:: -0.808510637785
# SLOPE:: -0.575757575238
# SLOPE:: -0.443786981935
# SLOPE:: -0.419642856696
# SLOPE:: -0.534482758071
# SLOPE:: -0.539999999356
# SLOPE:: -0.83774834404
# SLOPE:: -0.378378377769
# SLOPE:: -0.727272726397
# SLOPE:: -0.389473683722
# SLOPE:: -0.656249999185
# SLOPE:: -0.420833333124
# SLOPE:: 0.468468467965
# SLOPE:: -0.699029125405
# SLOPE:: -0.342105262621
# LEFT # 36 [-0.78155339760597853, -0.83854166614603143, -0.62121212093161271, -0.54999999934434896, -0.57281553331762203, -0.59836065515303161, -0.50450450396268809, -0.46153846121290137, -0.4433497534342295, -0.55084745707062599, -0.43939393899712242, -0.86559139729469603, -0.48507462643413879, -0.35955056131615992, -0.44239631312102418, -0.48484848426466221, -0.37931034430784694, -0.46153846121290137, -0.54761904710094222, -0.46428571403862873, -0.84259259166254752, -0.44444444390927368, -0.80851063778520227, -0.57575757523760873, -0.44378698193548205, -0.41964285669620244, -0.53448275807141976, -0.53999999935626986, -0.83774834404017418, -0.37837837776883487, -0.72727272639699325, -0.38947368372180124, -0.65624999918509275, -0.42083333312430315, -0.69902912540455564, -0.34210526262128782] [-0.62121212093161271, -0.54999999934434896, -0.57281553331762203, -0.59836065515303161, -0.50450450396268809, -0.46153846121290137, -0.4433497534342295, -0.55084745707062599, -0.43939393899712242, -0.48507462643413879, -0.44239631312102418, -0.48484848426466221, -0.37931034430784694, -0.46153846121290137, -0.54761904710094222, -0.46428571403862873, -0.44444444390927368, -0.57575757523760873, -0.44378698193548205, -0.41964285669620244, -0.53448275807141976, -0.53999999935626986, -0.37837837776883487, -0.38947368372180124, -0.65624999918509275, -0.42083333312430315]
# right # 6 [0.55999999866485595, 0.5555555551467446, 0.57608695614850591, 0.52459016290924554, 0.5520833329905549, 0.46846846796535324] [0.55999999866485595, 0.5555555551467446, 0.57608695614850591, 0.5520833329905549]
# y = [-0.52647567]x + 732
# y = [ 0.54800785]x + 64
# done
# SLOPE:: -0.870129869456
# SLOPE:: -0.782828282357
# SLOPE:: 0.574999999572
# SLOPE:: 0.532467532055
# SLOPE:: -0.361445782873
# SLOPE:: 0.586206895347
# SLOPE:: -0.573426572949
# SLOPE:: -0.526881720092
# SLOPE:: 0.536231883132
# SLOPE:: -0.505050504442
# SLOPE:: -0.787401574064
# SLOPE:: -0.530612244468
# SLOPE:: -0.509090908539
# SLOPE:: -0.834394903825
# SLOPE:: -0.619354838233
# SLOPE:: -0.527950310168
# SLOPE:: -0.574468084621
# SLOPE:: 0.628571427858
# SLOPE:: -0.697247705659
# SLOPE:: 0.599999999651
# SLOPE:: -0.703056768193
# SLOPE:: -0.534246574906
# SLOPE:: -0.65048543614
# SLOPE:: 0.5606060601
# SLOPE:: -0.704761903962
# SLOPE:: -0.303797467896
# SLOPE:: -0.576642335265
# SLOPE:: -0.758064514671
# SLOPE:: 0.343434343021
# SLOPE:: -0.338582676848
# SLOPE:: -0.499999999273
# SLOPE:: 0.567901233732
# SLOPE::
#  29%|██▊       | 2/7 [00:00<00:00,  9.90it/s]
#  -0.338983050163
# LEFT # 24 [-0.87012986945631454, -0.78282828235696766, -0.36144578287296569, -0.57342657294854704, -0.52688172009242373, -0.50505050444235644, -0.78740157406405054, -0.53061224446766053, -0.5090909085391967, -0.834394903825047, -0.61935483823333648, -0.52795031016809579, -0.57446808462069554, -0.69724770565946415, -0.70305676819296548, -0.53424657490625238, -0.65048543614035037, -0.70476190396176985, -0.30379746789600659, -0.57664233526466335, -0.75806451467147851, -0.33858267684754173, -0.49999999927311412, -0.3389830501625436] [-0.57342657294854704, -0.52688172009242373, -0.50505050444235644, -0.53061224446766053, -0.5090909085391967, -0.61935483823333648, -0.52795031016809579, -0.57446808462069554, -0.69724770565946415, -0.70305676819296548, -0.53424657490625238, -0.65048543614035037, -0.70476190396176985, -0.57664233526466335, -0.75806451467147851, -0.49999999927311412]
# right # 9 [0.57499999957159165, 0.53246753205535668, 0.58620689534687398, 0.5362318831315388, 0.62857142785779474, 0.59999999965109474, 0.56060606009977687, 0.34343434302080239, 0.56790123373210988] [0.57499999957159165, 0.53246753205535668, 0.58620689534687398, 0.5362318831315388, 0.62857142785779474, 0.59999999965109474, 0.56060606009977687, 0.56790123373210988]
# y = [-0.59132087]x + 758
# y = [ 0.56339526]x + 50
# done
#  43%|████▎     | 3/7 [00:00<00:00,  9.08it/s]
# SLOPE:: -0.865771811388
# SLOPE:: -0.807291666165
# SLOPE:: -0.36065573747
# SLOPE:: 0.528089886933
# SLOPE:: -0.806451611353
# SLOPE:: -0.807017543297
# SLOPE:: 0.570175438
# SLOPE:: -0.476190475289
# SLOPE:: -0.598360655153
# SLOPE:: -0.509999999392
# SLOPE:: -0.407407406508
# SLOPE:: -0.533898304545
# SLOPE:: -0.40298507391
# SLOPE:: -0.439655171962
# SLOPE:: -0.481132074931
# SLOPE:: -0.304687499716
# SLOPE:: -0.53072625663
# SLOPE:: -0.401459853665
# SLOPE:: 0.521126759688
# SLOPE:: -0.539999998713
# SLOPE:: -0.799999998093
# SLOPE:: -0.809523808375
# SLOPE:: -0.866666666041
# SLOPE:: 0.522388058772
# SLOPE:: -0.545454544272
# SLOPE:: 0.574803149067
# SLOPE:: -0.481751824398
# SLOPE:: -0.532110091161
# SLOPE:: -0.557692306414
# SLOPE:: -0.529411764176
# SLOPE:: -0.472727271703
# LEFT # 26 [-0.86577181138786552, -0.80729166616543402, -0.36065573746998081, -0.80645161135263677, -0.80701754329705266, -0.47619047528942338, -0.59836065515303161, -0.50999999939203267, -0.40740740650802321, -0.5338983045453759, -0.40298507390985727, -0.43965517196197429, -0.48113207493060933, -0.30468749971623765, -0.53072625662979045, -0.40145985366527193, -0.53999999871253967, -0.79999999809265132, -0.80952380837496718, -0.8666666660405169, -0.54545454427230455, -0.48175182439832631, -0.53211009116117003, -0.55769230641380574, -0.52941176417553948, -0.47272727170266399] [-0.47619047528942338, -0.59836065515303161, -0.50999999939203267, -0.40740740650802321, -0.5338983045453759, -0.40298507390985727, -0.43965517196197429, -0.48113207493060933, -0.53072625662979045, -0.40145985366527193, -0.53999999871253967, -0.54545454427230455, -0.48175182439832631, -0.53211009116117003, -0.55769230641380574, -0.52941176417553948, -0.47272727170266399]
# right # 5 [0.52808988693310988, 0.57017543800026138, 0.52112675968840638, 0.5223880587720372, 0.57480314906675689] [0.52808988693310988, 0.52112675968840638, 0.5223880587720372]
# y = [-0.47360015]x + 698
# y = [ 0.50275642]x + 106
# done
# SLOPE:: -0.810810810288
# SLOPE:: -0.867549668189
# SLOPE:: -0.309090908421
# SLOPE:: -0.359999999714
# SLOPE:: -0.303030302848
# SLOPE:: -0.316831682794
# SLOPE:: -0.395604395086
# SLOPE:: -0.424836600976
# SLOPE:: -0.579831932192
# SLOPE:: -0.423913042929
# SLOPE:: -0.458333332764
# SLOPE:: 0.475409835137
# SLOPE:: -0.485294117363
# SLOPE:: -0.866666666041
# SLOPE:: -0.327868851818
# SLOPE:: 0.523809523066
# SLOPE:: -0.460784313187
# SLOPE:: 0.532467531643
# SLOPE:: -0.304347825771
# SLOPE:: 0.607843135834
# SLOPE:: 0.568627449651
# SLOPE:: -0.835616436992
# SLOPE:: -0.528571428121
# SLOPE:: -0.559999998665
# LEFT # 19 [-0.81081081028834501, -0.86754966818927171, -0.30909090842097259, -0.35999999971389768, -0.30303030284785842, -0.31683168279436358, -0.39560439508615691, -0.42483660097617992, -0.57983193219225759, -0.42391304292897419, -0.45833333276419175, -0.48529411736347272, -0.8666666660405169, -0.32786885181827846, -0.46078431318696306, -0.30434782577146879, -0.83561643699159938, -0.52857142812135272, -0.55999999866485595]
# [-0.30909090842097259, -0.35999999971389768, -0.30303030284785842, -0.31683168279436358, -0.39560439508615691, -0.42483660097617992, -0.57983193219225759, -0.42391304292897419, -0.45833333276419175, -0.48529411736347272, -0.32786885181827846, -0.46078431318696306, -0.30434782577146879, -0.52857142812135272, -0.55999999866485595]
# right # 5 [0.47540983513650381, 0.52380952306615525, 0.53246753164318084, 0.60784313583410687, 0.56862744965126133] [0.47540983513650381, 0.52380952306615525, 0.53246753164318084, 0.56862744965126133]
# y = [-0.36730498]x + 668
# y = [ 0.48601165]x + 107
# done
# SLOPE:: -0.807909603976
# SLOPE:: -0.333333332671
# SLOPE:: -0.867647058063
# SLOPE:: -0.363636363278
# SLOPE:: -0.382352940841
# SLOPE:: -0.576470587831
# SLOPE:: -0.831325300011
# SLOPE:: -0.675438595785
# SLOPE:: -0.514285713702
# SLOPE:: -0.506607929249
# SLOPE:: -0.674999999329
# SLOPE:: -0.619469025895
# SLOPE:: -0.508620689132
# SLOPE:: -1.11764705726
# SLOPE:: -0.504201680167
# SLOPE:: -0.39999999947
# SLOPE:: -1.06976744038
# SLOPE:: -0.574324323862
# SLOPE:: -0.807692306952
# SLOPE:: -0.487603305305
# SLOPE:: -1.1999999978
# SLOPE:: -0.376344085539
# SLOPE:: -0.527999999496
# SLOPE:: -0.578231292048
# SLOPE:: -0.619999999261
# LEFT # 25 [-0.80790960397564782, -0.33333333267105952, -0.86764705806300302, -0.36363636327810883, -0.38235294084132337, -0.57647058783105498, -0.83132530001082294, -0.67543859578492493, -0.51428571370183207, -0.50660792924937281, -0.67499999932944776, -0.61946902589516406, -0.50862068913248004, -1.1176470572560717, -0.50420168016718048, -0.39999999947018094, -1.0697674403776021, -0.57432432386172438, -0.80769230695165828, -0.48760330530473683, -1.1999999977992131, -0.37634408553909987, -0.52799999949645993, -0.57823129204809154, -0.61999999926090243] [-0.38235294084132337, -0.57647058783105498, -0.67543859578492493, -0.51428571370183207, -0.50660792924937281, -0.67499999932944776, -0.61946902589516406, -0.50862068913248004, -0.50420168016718048, -0.39999999947018094, -0.57432432386172438, -0.48760330530473683, -0.52799999949645993, -0.57823129204809154, -0.61999999926090243]
# right # 0 [] []
# y = [-0.57659703]x + 753
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <timed eval> in <module>()
#
# <decorator-gen-175> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, progress_bar)
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# <decorator-gen-174> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, progress_bar)
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     135              for (k,v) in k.items()}
#     136
# --> 137     return f(clip, *new_a, **new_kw)
#
# <decorator-gen-173> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, progress_bar)
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, progress_bar)
#     347                            verbose=verbose, threads=threads,
#     348                            ffmpeg_params=ffmpeg_params,
# --> 349                            progress_bar=progress_bar)
#     350
#     351         if remove_temp and make_audio:
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/io/ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, progress_bar)
#     207
#     208     for t,frame in clip.iter_frames(progress_bar=progress_bar, with_times=True,
# --> 209                                     fps=fps, dtype="uint8"):
#     210         if withmask:
#     211             mask = (255*clip.mask.get_frame(t))
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tqdm/_tqdm.py in __iter__(self)
#     831 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     832
# --> 833             for obj in iterable:
#     834                 yield obj
#     835                 # Update and print the progressbar.
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in generator()
#     473         def generator():
#     474             for t in np.arange(0, self.duration, 1.0/fps):
# --> 475                 frame = self.get_frame(t)
#     476                 if (dtype is not None) and (frame.dtype != dtype):
#     477                     frame = frame.astype(dtype)
#
# <decorator-gen-138> in get_frame(self, t)
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in get_frame(self, t)
#      93                 return frame
#      94         else:
# ---> 95             return self.make_frame(t)
#      96
#      97     def fl(self, fun, apply_to=[], keep_duration=True):
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in <lambda>(t)
#     134
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#     138         if not keep_duration:
#
# ~/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/VideoClip.py in <lambda>(gf, t)
#     531         `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     532         """
# --> 533         return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#     534
#     535     # --------------------------------------------------------------
#
# <ipython-input-216-092624641a9d> in process_image(image)
#       2
#       3 def process_image(image):
# ----> 4     result = pipe.detect_lane(image)
#       5     print('done')
#       6     return result
#
# /src/pipe.py in detect_lane(rgb_img)
#      47         threshold=64,
#      48         min_line_len=50,
# ---> 49         max_line_gap=40)
#      50     img = helper.weighted_img(img, rgb_img)
#      51
#
# /src/helper.py in hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap)
#     195
#     196     line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
# --> 197     draw_lines2(line_img, lines)
#     198
#     199     return line_img
#
# /src/helper.py in draw_lines2(img, lines, color, thickness)
#     166     left_line = merge_lines(left_lines, h)
#     167     # print('right line')
# --> 168     right_line = merge_lines(right_lines, h)
#     169
#     170     for line in [left_line, right_line]:
#
# /src/helper.py in merge_lines(lines, h)
#      80 def merge_lines(lines, h):
#      81     line_pts = np.array(line2pts(lines))
# ---> 82     line_param = cv2.fitLine(line_pts, cv2.DIST_L2, 0, 0.01, 0.01)
#      83
#      84     return extrapolate_line(line_param, h * 0.6, h)
#
# error: /home/travis/miniconda/conda-bld/conda_1486587071158/work/opencv-3.1.0/modules/imgproc/src/linefit.cpp:603: error: (-215) npoints2 >= 0 || npoints3 >= 0 in function fitLine

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/challenge.mp4">
# </video>
